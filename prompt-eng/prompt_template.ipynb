# %% [markdown]
# # Prompt Template Prompting
#
# Prompt Template Prompting refers to a technique where predefined templates are used to construct effective prompts that guide large language models (LLMs) to generate responses tailored to specific use cases. The templates typically contain static text combined with dynamic input variables, allowing for consistent, reusable, and customizable prompts.
#
# Prompt templates are widely used across various domains, such as:
# * **Question Generation**: Templates can generate quiz questions by filling in variables related to topics.
# * **Text Summarization**: Static instructions combined with variable documents or inputs allow flexible summarization.
# * **Coding Assistance**: Dynamic prompts help LLMs generate code snippets for different programming tasks.
#
# ## References:
#
# * (OpenAI Documentation for Prompt Engineering)[https://platform.openai.com/docs/guides/prompt-engineering]

# %% [markdown]
# ## Running this code on MyBind.org
#
# Note: remember that you will need to **adjust CONFIG** with **proper URL and API_KEY**!
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/GenILab-FAU/prompt-eng/HEAD?urlpath=%2Fdoc%2Ftree%2Fprompt-eng%2Fprompt_template.ipynb)

# %%
import json
import re
import time
import statistics
from _pipeline import create_payload, model_req

# Load previous best prompts with improved error handling
def load_prompt_history():
    try:
        with open("best_prompts.json", "r") as file:
            return json.load(file)
    except (FileNotFoundError, json.JSONDecodeError):
        print("Creating new prompt history database")
        return {}

# Enhanced domain-specific terminology with importance weights
important_terms = {
    "functional requirements": 15,
    "non-functional requirements": 15,
    "real-time study support": 10,
    "personalized tutoring": 10,
    "exam preparation": 10,
    "user experience": 12,
    "response time": 8,
    "scalability": 8,
    "security": 12,
    "integration": 10,
    "data privacy": 12,
    "accessibility": 10
}

def enhanced_score_response(response, metrics_only=False):
    """
    Enhanced scoring function with multiple evaluation dimensions
    Returns tuple: (final_score, detailed_metrics, critique)
    """
    # Initialize metrics dictionary
    metrics = {
        "word_count": len(response.split()),
        "keyword_matches": 0,
        "keyword_score": 0,
        "ai_critique_score": 0,
        "readability_score": 0
    }
    
    # Calculate keyword presence and weighted score
    for term, weight in important_terms.items():
        if term.lower() in response.lower():
            metrics["keyword_matches"] += 1
            metrics["keyword_score"] += weight
    
    # Simple readability metric (avg sentence length - prefer 15-20 words)
    sentences = [s.strip() for s in re.split(r'[.!?]', response) if s.strip()]
    if sentences:
        avg_sentence_length = statistics.mean([len(s.split()) for s in sentences])
        # Penalize sentences that are too short or too long
        if avg_sentence_length < 8:
            metrics["readability_score"] = 5
        elif avg_sentence_length > 30:
            metrics["readability_score"] = 6
        else:
            metrics["readability_score"] = 10
    
    # If only want metrics without AI critique (for faster iterations)
    if metrics_only:
        metrics["final_score"] = (
            metrics["word_count"] * 0.2 +
            metrics["keyword_score"] * 2 +
            metrics["readability_score"] * 5
        )
        return metrics["final_score"], metrics, "No critique requested"
        
    # AI-based multidimensional critique
    critic_prompt = f"""
    Perform a detailed evaluation of the following requirement analysis response for an AI-powered Study Companion Discord Bot.
    
    Evaluate based on these specific criteria:
    1. Clarity (1-10): Is the response well-structured, organized logically, and easy to understand?
    2. Completeness (1-10): Does it thoroughly cover both functional and non-functional requirements?
    3. Technical Accuracy (1-10): Are the statements factually correct and aligned with software engineering best practices?
    4. Specificity (1-10): Does it provide concrete, actionable details rather than vague statements?
    5. Feasibility (1-10): Are the requirements realistic and implementable?
    
    Response to evaluate:
    {response}
    
    Format your response exactly as follows:
    Clarity: [score]/10
    Completeness: [score]/10
    Technical Accuracy: [score]/10
    Specificity: [score]/10
    Feasibility: [score]/10
    Overall: [average score]/10
    
    Explanation: [brief justification for scores and specific improvement suggestions]
    """

    # Call the AI model to critique the response
    payload_critic = create_payload(
        target="ollama",
        model="llama3.2:latest",
        prompt=critic_prompt,
        temperature=0.4  # Lower temperature for more consistent evaluation
    )
    
    _, critic_feedback = model_req(payload_critic)
    
    # Extract all scores using regex
    scores = {}
    for criterion in ["Clarity", "Completeness", "Technical Accuracy", "Specificity", "Feasibility", "Overall"]:
        match = re.search(rf"{criterion}:\s*(\d+(?:\.\d+)?)/10", critic_feedback)
        if match:
            scores[criterion.lower()] = float(match.group(1))
    
    # Calculate average score if "Overall" wasn't extracted
    if "overall" not in scores and len(scores) > 0:
        scores["overall"] = sum(scores.values()) / len(scores)
    
    # Use overall score or default to 5
    critic_score = scores.get("overall", 5)
    metrics["ai_critique_score"] = critic_score * 10  # Scale to 0-100
    
    # Calculate final weighted score
    metrics["final_score"] = (
        metrics["word_count"] * 0.2 +           # 20% weight for length
        metrics["keyword_score"] * 2 +          # 40% weight for keywords
        metrics["ai_critique_score"] * 3 +      # 30% weight for AI critique
        metrics["readability_score"] * 5        # 10% weight for readability
    )
    
    return metrics["final_score"], metrics, critic_feedback

def generate_prompt_variations(base_prompt, n=3):
    """Generate multiple variations of a prompt to test effectiveness"""
    variation_prompt = f"""
    Create {n} variations of the following prompt. Each variation should maintain the same goal
    but experiment with different structures, emphasis, or approaches to potentially improve results.
    Make each variation distinctly different in structure or strategy.
    
    Original prompt:
    {base_prompt}
    
    Format your response as:
    VARIATION 1:
    [First complete prompt variation]
    
    VARIATION 2:
    [Second complete prompt variation]
    
    VARIATION 3:
    [Third complete prompt variation]
    """
    
    payload = create_payload(
        target="ollama",
        model="llama3.2:latest",
        prompt=variation_prompt,
        temperature=0.8,  # Higher temperature for more creative variations
        num_predict=2048
    )
    
    _, variations_text = model_req(payload)
    
    # Extract variations using regex
    variations = []
    for i in range(1, n+1):
        pattern = rf"VARIATION {i}:(.*?)(?:VARIATION {i+1}:|$)"
        match = re.search(pattern, variations_text, re.DOTALL)
        if match:
            variations.append(match.group(1).strip())
    
    # If extraction failed, fall back to simpler method
    if not variations:
        variations = [base_prompt]
        print("Failed to generate distinct variations")
    
    return variations

# Main optimization process
def optimize_prompt_pipeline():
    # Load prompt history at the beginning of the function
    prompt_history = load_prompt_history()
    
    # Step 1: Generate initial meta-prompt
    meta_prompt = (
        "Create a highly structured prompt that extracts detailed functional and non-functional "
        "requirements for an AI-powered Study Companion Discord Bot. The structured prompt should "
        "elicit comprehensive, technically precise, and actionable requirements spanning user "
        "interaction, performance criteria, security measures, and integration capabilities. "
        "Include specific sections for real-time study support, personalized tutoring, and exam preparation. "
        "The prompt should guide the response to be well-organized with clear categorization."
    )
    
    payload_meta = create_payload(
        target="ollama",
        model="llama3.2:latest",
        prompt=meta_prompt,
        temperature=0.7
    )
    _, base_prompt = model_req(payload_meta)
    print("✓ Generated base prompt")
    
    # Step 2: Generate multiple prompt variations
    prompt_variations = generate_prompt_variations(base_prompt, n=3)
    print(f"✓ Created {len(prompt_variations)} prompt variations")
    
    # Step 3: Test all variations
    results = []
    
    for i, prompt in enumerate(prompt_variations):
        print(f"Testing variation {i+1}...")
        
        # Execute prompt
        payload_exec = create_payload(
            target="ollama",
            model="llama3.2:latest",
            prompt=prompt,
            temperature=0.9,  # Slightly higher for creative requirements
            num_ctx=4096,
            num_predict=2048
        )
        _, response = model_req(payload_exec)
        
        # Score the response
        score, metrics, critique = enhanced_score_response(response)
        
        results.append({
            "prompt": prompt,
            "response": response,
            "score": score,
            "metrics": metrics,
            "critique": critique
        })
        
        print(f"  Score: {score:.2f}")
    
    # Sort by score (descending)
    results.sort(key=lambda x: x["score"], reverse=True)
    best_result = results[0]
    
    # Step 4: Refine the best prompt based on critique
    refinement_prompt = f"""
    Refine this prompt based on the following critique of the response it generated.
    
    Original prompt:
    {best_result["prompt"]}
    
    Response critique:
    {best_result["critique"]}
    
    Create an improved version of the prompt that addresses the weaknesses identified in the critique
    while maintaining its strengths. Focus especially on eliciting more specific, actionable, and
    comprehensive requirements.
    """
    
    payload_refine = create_payload(
        target="ollama",
        model="llama3.2:latest",
        prompt=refinement_prompt,
        temperature=0.6
    )
    _, refined_prompt = model_req(payload_refine)
    print("✓ Generated refined prompt")
    
    # Step 5: Test the refined prompt
    payload_refined_exec = create_payload(
        target="ollama",
        model="llama3.2:latest",
        prompt=refined_prompt,
        temperature=0.9,
        num_ctx=4096,
        num_predict=2048
    )
    _, refined_response = model_req(payload_refined_exec)
    
    refined_score, refined_metrics, refined_critique = enhanced_score_response(refined_response)
    print(f"✓ Refined prompt score: {refined_score:.2f}")
    
    # Step 6: Compare and select the best overall
    all_results = results + [{
        "prompt": refined_prompt,
        "response": refined_response,
        "score": refined_score,
        "metrics": refined_metrics,
        "critique": refined_critique
    }]
    
    all_results.sort(key=lambda x: x["score"], reverse=True)
    champion = all_results[0]
    
    # Save to history
    timestamp = time.strftime("%Y%m%d_%H%M%S")
    prompt_history[timestamp] = {
        "prompt": champion["prompt"],
        "score": champion["score"],
        "metrics": champion["metrics"]
    }
    
    # Save top 3 prompts to file
    with open("best_prompts.json", "w") as file:
        # Only store recent and high-scoring prompts (up to 20)
        if len(prompt_history) > 20:
            sorted_history = sorted(
                prompt_history.items(),
                key=lambda x: x[1].get("score", 0),
                reverse=True
            )
            prompt_history = dict(sorted_history[:20])
        
        json.dump(prompt_history, file, indent=4)
    
    # Output Results
    print("\n" + "="*50)
    print("OPTIMIZATION RESULTS")
    print("="*50)
    print(f"🏆 Best Score: {champion['score']:.2f}")
    print(f"📊 Metrics: {champion['metrics']}")
    print("\n✅ BEST OPTIMIZED PROMPT:")
    print("-"*50)
    print(champion["prompt"])
    print("-"*50)
    print("\n📜 GENERATED RESPONSE:")
    print("-"*50)
    print(champion["response"][:500] + "..." if len(champion["response"]) > 500 else champion["response"])
    print("-"*50)
    print("\n🔍 CRITIQUE:")
    print("-"*50)
    print(champion["critique"])
    print("="*50)
    
    return champion

# Run the optimization pipeline
if __name__ == "__main__":
    optimize_prompt_pipeline()
# Out:
# {'model': 'llama3.2:latest', 'prompt': 'Create a highly structured prompt that extracts detailed functional and non-functional requirements for an AI-powered Study Companion Discord Bot. The structured prompt should elicit comprehensive, technically precise, and actionable requirements spanning user interaction, performance criteria, security measures, and integration capabilities. Include specific sections for real-time study support, personalized tutoring, and exam preparation. The prompt should guide the response to be well-organized with clear categorization.', 'stream': False, 'options': {'temperature': 0.7}}
# ✓ Generated base prompt
# {'model': 'llama3.2:latest', 'prompt': '\n    Create 3 variations of the following prompt. Each variation should maintain the same goal\n    but experiment with different structures, emphasis, or approaches to potentially improve results.\n    Make each variation distinctly different in structure or strategy.\n    \n    Original prompt:\n    **AI-Powered Study Companion Discord Bot Requirements**\n\n**I. User Interaction Requirements**\n\n1. **User Onboarding**\n\t* Create a user-friendly sign-up process for students to register and create their profiles.\n\t* Include mandatory fields such as username, email, and password.\n\t* Provide an option for users to add friends or join study groups.\n2. **Channel Management**\n\t* Allow users to create and manage different channels (e.g., general discussion, Q&A, resource sharing).\n\t* Enable channel moderation tools (e.g., kick/ban members, set channel permissions).\n3. **Message Input/Output**\n\t* Implement a message input system that allows users to type, paste, or share files.\n\t* Provide an option for users to upload and download files (e.g., PDFs, images, audio files).\n\n**II. Real-Time Study Support Requirements**\n\n1. **Live Q&A Sessions**\n\t* Enable live Q&A sessions with AI-powered chatbots that provide real-time answers to user queries.\n\t* Allow moderators to join and participate in these sessions.\n2. **Study Group Management**\n\t* Facilitate the creation of study groups, including group management tools (e.g., member list, group chat).\n\t* Enable group members to share resources, ask questions, and collaborate on assignments.\n3. **Real-Time Feedback System**\n\t* Develop an AI-powered feedback system that provides users with instant feedback on their work (e.g., math problems, essays).\n\n**III. Personalized Tutoring Requirements**\n\n1. **User Profiling**\n\t* Create user profiles that capture their strengths, weaknesses, learning style, and goals.\n\t* Use this data to provide personalized recommendations for resources, study groups, and tutoring sessions.\n2. **AI-Powered Tutoring**\n\t* Develop an AI-powered tutoring system that provides one-on-one support to users based on their profile information.\n\t* Utilize natural language processing (NLP) and machine learning algorithms to offer tailored guidance.\n3. **Tutor Availability Management**\n\t* Schedule and manage tutor availability, including setting up appointments and reminders.\n\t* Allow tutors to cancel or reschedule sessions with users.\n\n**IV. Exam Preparation Requirements**\n\n1. **Practice Questions Database**\n\t* Develop a comprehensive database of practice questions for various subjects (e.g., math, science, English).\n\t* Provide options for users to search and filter questions based on topic, difficulty level, and format.\n2. **Exam Simulation Tool**\n\t* Create an exam simulation tool that mimics real-world testing conditions.\n\t* Allow users to take simulated exams, track their scores, and receive feedback on their performance.\n3. **Personalized Study Plans**\n\t* Generate personalized study plans based on user performance data (e.g., practice questions completed, time spent studying).\n\t* Provide recommendations for adjusting the study plan as needed.\n\n**V. Performance Criteria Requirements**\n\n1. **Response Time**\n\t* Ensure a response time of ≤ 2 seconds for all user interactions.\n\t* Monitor and optimize the system to maintain this response time.\n2. **Accuracy**\n\t* Achieve an accuracy rate of ≥ 95% for AI-powered chatbots and tutoring sessions.\n\t* Continuously monitor and improve the system to maintain this accuracy rate.\n3. **System Uptime**\n\t* Maintain a system uptime of ≥ 99.5%.\n\t* Implement regular backups and disaster recovery procedures.\n\n**VI. Security Measures Requirements**\n\n1. **Data Encryption**\n\t* Encrypt all user data (e.g., profiles, messages, files) using end-to-end encryption.\n2. **Password Management**\n\t* Enforce strong password policies f ...
# ✓ Created 3 prompt variations
# Testing variation 1...
# {'model': 'llama3.2:latest', 'prompt': 'Prioritized Requirements**\n\n**I. Essential Features**\n\n1. **User Onboarding**\n\t* Create a user-friendly sign-up process for students to register and create their profiles.\n\t* Include mandatory fields such as username, email, and password.\n2. **Channel Management**\n\t* Allow users to create and manage different channels (e.g., general discussion, Q&A, resource sharing).\n3. **Message Input/Output**\n\t* Implement a message input system that allows users to type, paste, or share files.\n\n**II. Critical Functionality**\n\n1. **Live Q&A Sessions**\n\t* Enable live Q&A sessions with AI-powered chatbots that provide real-time answers to user queries.\n2. **Study Group Management**\n\t* Facilitate the creation of study groups, including group management tools (e.g., member list, group chat).\n3. **Real-Time Feedback System**\n\t* Develop an AI-powered feedback system that provides users with instant feedback on their work.\n\n**III. Recommended Enhancements**\n\n1. **User Profiling**\n\t* Create user profiles that capture their strengths, weaknesses, learning style, and goals.\n2. **AI-Powered Tutoring**\n\t* Develop an AI-powered tutoring system that provides one-on-one support to users based on their profile information.\n3. **Tutor Availability Management**\n\t* Schedule and manage tutor availability, including setting up appointments and reminders.\n\n**IV. Performance and Security**\n\n1. **Response Time**\n\t* Ensure a response time of ≤ 2 seconds for all user interactions.\n2. **Data Encryption**\n\t* Encrypt all user data (e.g., profiles, messages, files) using end-to-end encryption.\n\nThis variation prioritizes the most essential features and functionality, while still incorporating critical enhancements to improve the overall experience. By focusing on these core requirements, the bot can provide a solid foundation for supporting students in their academic pursuits.\n\n**', 'stream': False, 'options': {'temperature': 0.9, 'num_ctx': 4096, 'num_predict': 2048}}
# {'model': 'llama3.2:latest', 'prompt': "\n    Perform a detailed evaluation of the following requirement analysis response for an AI-powered Study Companion Discord Bot.\n    \n    Evaluate based on these specific criteria:\n    1. Clarity (1-10): Is the response well-structured, organized logically, and easy to understand?\n    2. Completeness (1-10): Does it thoroughly cover both functional and non-functional requirements?\n    3. Technical Accuracy (1-10): Are the statements factually correct and aligned with software engineering best practices?\n    4. Specificity (1-10): Does it provide concrete, actionable details rather than vague statements?\n    5. Feasibility (1-10): Are the requirements realistic and implementable?\n    \n    Response to evaluate:\n    Based on the provided prioritized requirements, I'll create a rough outline of how to develop the bot. Please note that this is just an initial estimate and might require adjustments as development progresses.\n\n**Initial Estimate**\n\n1. **User Onboarding** (II. Essential Features)\n\t* Create a user-friendly sign-up process with mandatory fields: username, email, and password.\n\t* Use existing authentication libraries or services to simplify the implementation.\n2. **Channel Management** (I. Essential Features)\n\t* Implement a basic channel management system that allows users to create and manage channels using existing APIs or frameworks (e.g., Discord API).\n3. **Message Input/Output** (I. Essential Features)\n\t* Develop a message input system using a template engine or markup language like Handlebars or Jinja2.\n\t* Use existing libraries for file handling, such as Multer (Node.js) or Python's Django.\n\n2. **Live Q&A Sessions** (II. Critical Functionality)\n\t* Integrate an AI-powered chatbot using an existing library like Dialogflow, Rasa, or Botkit.\n\t* Set up a basic infrastructure to handle live sessions, including server-side rendering and client-side JavaScript libraries.\n\n3. **Study Group Management** (II. Critical Functionality)\n\t* Use existing APIs or frameworks for group management tools (e.g., Discord API).\n\t* Develop a study group creation and management system using templates and existing data storage solutions.\n\n4. **Real-Time Feedback System** (II. Critical Functionality)\n\t* Implement an AI-powered feedback system that provides instant feedback on user work.\n\t* Use machine learning libraries like TensorFlow, PyTorch, or Scikit-Learn for development.\n\n5. **User Profiling** (III. Recommended Enhancements)\n\t* Collect user data and create profiles using existing data storage solutions (e.g., MongoDB, PostgreSQL).\n\t* Develop a system to update profiles with new information.\n\n6. **AI-Powered Tutoring** (III. Recommended Enhancements)\n\t* Integrate an AI-powered tutoring system using existing libraries like Dialogflow or Rasa.\n\t* Implement scheduling and management tools for tutor availability.\n\n7. **Tutor Availability Management** (III. Recommended Enhancements)\n\t* Use existing APIs or frameworks to schedule and manage tutor appointments.\n\t* Develop a reminder system using server-side or client-side JavaScript libraries.\n\n8. **Performance and Security**\n\t* Optimize response time by implementing techniques like caching, message queuing, or async programming.\n\t* Encrypt user data using end-to-end encryption methods (e.g., SSL/TLS) and secure storage solutions (e.g., encrypted databases).\n\nThis initial estimate should provide a solid foundation for the bot. However, please note that actual development will require more detail, testing, and refinement to ensure a stable and reliable platform.\n\n**Assumptions**\n\n* The bot will be built using existing technologies and frameworks.\n* Existing APIs and libraries are utilized whenever possible.\n* Development team familiarity with specific technologies is assumed.\n* Initial estimates may need adjustments as development progresses.\n\nPlease let me know if you'd like  ...
#   Score: 379.40
# Testing variation 2...
# {'model': 'llama3.2:latest', 'prompt': "Feature-Driven Approach**\n\n**I. Core Features**\n\n1. **Practice Questions Database**\n\t* Develop a comprehensive database of practice questions for various subjects (e.g., math, science, English).\n2. **Exam Simulation Tool**\n\t* Create an exam simulation tool that mimics real-world testing conditions.\n3. **Personalized Study Plans**\n\t* Generate personalized study plans based on user performance data (e.g., practice questions completed, time spent studying).\n\n**II. Advanced Features**\n\n1. **AI-Powered Tutoring**\n\t* Develop an AI-powered tutoring system that provides one-on-one support to users based on their profile information.\n2. **Tutor Availability Management**\n\t* Schedule and manage tutor availability, including setting up appointments and reminders.\n3. **Resource Sharing**\n\t* Enable users to share resources (e.g., PDFs, images, audio files) between users.\n\n**III. User Experience Enhancements**\n\n1. **User Feedback Mechanism**\n\t* Implement a user feedback mechanism that allows users to report issues or suggest improvements.\n2. **Analytics and Reporting**\n\t* Develop analytics tools to track system performance, user engagement, and study progress.\n3. **Accessibility Features**\n\t* Incorporate accessibility features (e.g., font size adjustment, high contrast mode) for users with disabilities.\n\nThis variation focuses on the core features that drive the bot's functionality, while still incorporating advanced features and user experience enhancements to make the platform more engaging and supportive.\n\n**", 'stream': False, 'options': {'temperature': 0.9, 'num_ctx': 4096, 'num_predict': 2048}}
# {'model': 'llama3.2:latest', 'prompt': '\n    Perform a detailed evaluation of the following requirement analysis response for an AI-powered Study Companion Discord Bot.\n    \n    Evaluate based on these specific criteria:\n    1. Clarity (1-10): Is the response well-structured, organized logically, and easy to understand?\n    2. Completeness (1-10): Does it thoroughly cover both functional and non-functional requirements?\n    3. Technical Accuracy (1-10): Are the statements factually correct and aligned with software engineering best practices?\n    4. Specificity (1-10): Does it provide concrete, actionable details rather than vague statements?\n    5. Feasibility (1-10): Are the requirements realistic and implementable?\n    \n    Response to evaluate:\n    Based on the provided specification, I can help you create a detailed project plan or a technical design document for the feature-driven approach of creating an educational platform.\n\nProject Plan:\n\nI. Core Features (Estimated Time: 12-16 weeks)\n\n1. **Practice Questions Database**\n\t* Requirements Gathering: 2 weeks\n\t* Data Collection and Curation: 4 weeks\n\t* Development and Testing: 6 weeks\n\t* Deployment: 1 week\n2. **Exam Simulation Tool**\n\t* Requirements Gathering: 2 weeks\n\t* Front-end Development (e.g., React, Angular): 8 weeks\n\t* Back-end Development (e.g., Node.js, Django): 4 weeks\n\t* Testing and Quality Assurance: 4 weeks\n3. **Personalized Study Plans**\n\t* Requirements Gathering: 1 week\n\t* Data Analytics and Machine Learning Integration: 6 weeks\n\t* Front-end Development (e.g., React, Angular): 8 weeks\n\t* Back-end Development (e.g., Node.js, Django): 4 weeks\n\t* Testing and Quality Assurance: 4 weeks\n\nII. Advanced Features (Estimated Time: 10-12 weeks)\n\n1. **AI-Powered Tutoring**\n\t* Requirements Gathering: 2 weeks\n\t* Natural Language Processing (NLP) Integration: 8 weeks\n\t* Front-end Development (e.g., React, Angular): 6 weeks\n\t* Back-end Development (e.g., Node.js, Django): 4 weeks\n\t* Testing and Quality Assurance: 4 weeks\n2. **Tutor Availability Management**\n\t* Requirements Gathering: 1 week\n\t* Scheduling Algorithm Development: 6 weeks\n\t* Front-end Development (e.g., React, Angular): 6 weeks\n\t* Back-end Development (e.g., Node.js, Django): 4 weeks\n\t* Testing and Quality Assurance: 4 weeks\n3. **Resource Sharing**\n\t* Requirements Gathering: 1 week\n\t* File Upload and Storage Integration: 4 weeks\n\t* Front-end Development (e.g., React, Angular): 6 weeks\n\t* Back-end Development (e.g., Node.js, Django): 4 weeks\n\t* Testing and Quality Assurance: 4 weeks\n\nIII. User Experience Enhancements (Estimated Time: 8-10 weeks)\n\n1. **User Feedback Mechanism**\n\t* Requirements Gathering: 1 week\n\t* Front-end Development (e.g., React, Angular): 4 weeks\n\t* Back-end Development (e.g., Node.js, Django): 2 weeks\n\t* Testing and Quality Assurance: 2 weeks\n2. **Analytics and Reporting**\n\t* Requirements Gathering: 1 week\n\t* Data Analytics and Visualization Tools Integration: 8 weeks\n\t* Front-end Development (e.g., React, Angular): 4 weeks\n\t* Back-end Development (e.g., Node.js, Django): 2 weeks\n\t* Testing and Quality Assurance: 2 weeks\n3. **Accessibility Features**\n\t* Requirements Gathering: 1 week\n\t* Accessibility Tool Integration (e.g., WAVE, Lighthouse): 4 weeks\n\t* Front-end Development (e.g., React, Angular): 6 weeks\n\t* Back-end Development (e.g., Node.js, Django): 2 weeks\n\t* Testing and Quality Assurance: 2 weeks\n\nTotal Estimated Time: 40-48 weeks\n    \n    Format your response exactly as follows:\n    Clarity: [score]/10\n    Completeness: [score]/10\n    Technical Accuracy: [score]/10\n    Specificity: [score]/10\n    Feasibility: [score]/10\n    Overall: [average score]/10\n    \n    Explanation: [brief justification for scores and specific improvement suggestions]\n    ', 'stream': False, 'options': {'temperature': 0.4}}
#   Score: 376.00
# Testing variation 3...
# {'model': 'llama3.2:latest', 'prompt': 'Modular Architecture**\n\n**I. Core Modules**\n\n1. **User Management Module**\n\t* Handle user registration, profile creation, and authentication.\n2. **Channel Management Module**\n\t* Allow users to create and manage different channels (e.g., general discussion, Q&A, resource sharing).\n3. **Message Input/Output Module**\n\t* Implement a message input system that allows users to type, paste, or share files.\n\n**II. Functional Modules**\n\n1. **Live Q&A Session Module**\n\t* Enable live Q&A sessions with AI-powered chatbots that provide real-time answers to user queries.\n2. **Study Group Management Module**\n\t* Facilitate the creation of study groups, including group management tools (e.g., member list, group chat).\n3. **Real-Time Feedback System Module**\n\t* Develop an AI-powered feedback system that provides users with instant feedback on their work.\n\n**III. Integration Modules**\n\n1. **LMS Integration Module**\n\t* Integrate the Discord bot with popular LMS platforms (e.g., Canvas, Blackboard).\n2. **Resource Sharing Module**\n\t* Enable users to share resources (e.g., PDFs, images, audio files) between users.\n3. **Analytics and Reporting Module**\n\t* Develop analytics tools to track system performance, user engagement, and study progress.\n\nThis variation adopts a modular architecture, where each module serves a specific purpose and can be developed and maintained independently. This approach allows for greater flexibility, scalability, and maintainability in the long run.', 'stream': False, 'options': {'temperature': 0.9, 'num_ctx': 4096, 'num_predict': 2048}}
# {'model': 'llama3.2:latest', 'prompt': '\n    Perform a detailed evaluation of the following requirement analysis response for an AI-powered Study Companion Discord Bot.\n    \n    Evaluate based on these specific criteria:\n    1. Clarity (1-10): Is the response well-structured, organized logically, and easy to understand?\n    2. Completeness (1-10): Does it thoroughly cover both functional and non-functional requirements?\n    3. Technical Accuracy (1-10): Are the statements factually correct and aligned with software engineering best practices?\n    4. Specificity (1-10): Does it provide concrete, actionable details rather than vague statements?\n    5. Feasibility (1-10): Are the requirements realistic and implementable?\n    \n    Response to evaluate:\n    **Modular Architecture Design Document**\n\nIntroduction:\nThe proposed modular architecture is designed to provide a scalable and maintainable foundation for the development of an educational platform. The platform will consist of several modules that work together to deliver a comprehensive user experience.\n\nCore Modules:\n\n1. **User Management Module**\n\t* This module will be responsible for handling user registration, profile creation, and authentication.\n\t* It will use a combination of backend and frontend technologies (e.g., Node.js, Express, React) to handle user data management.\n2. **Channel Management Module**\n\t* This module will allow users to create and manage different channels (e.g., general discussion, Q&A, resource sharing).\n\t* It will utilize a database-driven approach (e.g., MongoDB, PostgreSQL) to store channel information and user interactions.\n3. **Message Input/Output Module**\n\t* This module will implement a message input system that allows users to type, paste, or share files.\n\t* It will use WebSockets or WebRTC to establish real-time communication between clients and the server.\n\nFunctional Modules:\n\n1. **Live Q&A Session Module**\n\t* This module will enable live Q&A sessions with AI-powered chatbots that provide real-time answers to user queries.\n\t* It will integrate with natural language processing (NLP) libraries (e.g., spaCy, Stanford CoreNLP) and machine learning frameworks (e.g., TensorFlow, PyTorch).\n2. **Study Group Management Module**\n\t* This module will facilitate the creation of study groups, including group management tools (e.g., member list, group chat).\n\t* It will use a combination of frontend and backend technologies (e.g., React, Node.js, Express) to handle user interactions and data storage.\n3. **Real-Time Feedback System Module**\n\t* This module will develop an AI-powered feedback system that provides users with instant feedback on their work.\n\t* It will utilize machine learning frameworks (e.g., TensorFlow, PyTorch) and NLP libraries (e.g., spaCy, Stanford CoreNLP).\n\nIntegration Modules:\n\n1. **LMS Integration Module**\n\t* This module will integrate the Discord bot with popular LMS platforms (e.g., Canvas, Blackboard).\n\t* It will use APIs or webhooks to establish communication between the Discord bot and the LMS platform.\n2. **Resource Sharing Module**\n\t* This module will enable users to share resources (e.g., PDFs, images, audio files) between users.\n\t* It will utilize cloud storage services (e.g., Google Drive, Dropbox) or object storage services (e.g., Amazon S3).\n3. **Analytics and Reporting Module**\n\t* This module will develop analytics tools to track system performance, user engagement, and study progress.\n\t* It will use data visualization libraries (e.g., D3.js, Matplotlib) and database-driven approaches (e.g., MongoDB, PostgreSQL).\n\n**Benefits of Modular Architecture**\n\n1.  **Scalability**: The modular architecture allows for easy addition or removal of modules as needed, making it easier to scale the platform.\n2.  **Flexibility**: Each module can be developed and maintained independently, allowing for greater flexibility in the development process.\n3.  **Maintaina ...
#   Score: 417.00
# {'model': 'llama3.2:latest', 'prompt': '\n    Refine this prompt based on the following critique of the response it generated.\n    \n    Original prompt:\n    Modular Architecture**\n\n**I. Core Modules**\n\n1. **User Management Module**\n\t* Handle user registration, profile creation, and authentication.\n2. **Channel Management Module**\n\t* Allow users to create and manage different channels (e.g., general discussion, Q&A, resource sharing).\n3. **Message Input/Output Module**\n\t* Implement a message input system that allows users to type, paste, or share files.\n\n**II. Functional Modules**\n\n1. **Live Q&A Session Module**\n\t* Enable live Q&A sessions with AI-powered chatbots that provide real-time answers to user queries.\n2. **Study Group Management Module**\n\t* Facilitate the creation of study groups, including group management tools (e.g., member list, group chat).\n3. **Real-Time Feedback System Module**\n\t* Develop an AI-powered feedback system that provides users with instant feedback on their work.\n\n**III. Integration Modules**\n\n1. **LMS Integration Module**\n\t* Integrate the Discord bot with popular LMS platforms (e.g., Canvas, Blackboard).\n2. **Resource Sharing Module**\n\t* Enable users to share resources (e.g., PDFs, images, audio files) between users.\n3. **Analytics and Reporting Module**\n\t* Develop analytics tools to track system performance, user engagement, and study progress.\n\nThis variation adopts a modular architecture, where each module serves a specific purpose and can be developed and maintained independently. This approach allows for greater flexibility, scalability, and maintainability in the long run.\n    \n    Response critique:\n    Clarity: 8/10\n\nThe response is well-structured, with clear headings and concise descriptions of each module. However, some sections feel a bit lengthy and could be broken up into smaller paragraphs for easier reading.\n\nCompleteness: 7/10\n\nWhile the document covers most functional requirements, it lacks specific details on how to implement certain features or handle edge cases. For example, there is no discussion on data security, user authentication protocols, or scalability strategies. Additionally, some modules (e.g., Live Q&A Session Module) seem to overlap with others (e.g., Message Input/Output Module), which could lead to confusion.\n\nTechnical Accuracy: 6/10\n\nSome statements are factually incorrect or overly optimistic. For instance, the claim that "WebSockets or WebRTC can establish real-time communication between clients and the server" is not entirely accurate. While these technologies can facilitate real-time communication, they require additional setup and configuration to achieve seamless integration.\n\nSpecificity: 5/10\n\nMany requirements feel vague or open-ended, making it difficult to determine concrete implementation details. For example, the "resource sharing module" could be implemented using various cloud storage services, but no specific details are provided on how to integrate these services with the Discord bot.\n\nFeasibility: 4/10\n\nSome modules seem overly ambitious or require significant resources to implement effectively. For instance, developing an AI-powered feedback system that provides instant feedback on user work may be challenging and resource-intensive. Additionally, integrating with popular LMS platforms could be complex and time-consuming.\n\nOverall: 6/10\n\nWhile the modular architecture design is a good starting point, it requires more specificity, technical accuracy, and feasibility considerations to ensure successful implementation. Recommendations include:\n\n* Break up lengthy sections into smaller paragraphs\n* Provide more concrete details on implementation strategies and edge cases\n* Clarify overlapping or redundant modules\n* Conduct thorough feasibility assessments for each module\n* Consider seeking input from experts in relevant fields (e.g., AI, LMS platforms) to ensure technical accu ...
# ✓ Generated refined prompt
# {'model': 'llama3.2:latest', 'prompt': 'Here is a refined version of the prompt, addressing the weaknesses identified in the critique:\n\n**Modular Architecture**\n\n**I. Core Modules**\n\n1. **User Management Module**\n\t* Handle user registration, profile creation, and authentication using industry-standard protocols (e.g., OAuth 2.0).\n\t* Implement a robust password hashing algorithm to ensure data security.\n\t* Develop a user profile management system that allows users to update their information and set notifications for account updates.\n2. **Channel Management Module**\n\t* Allow users to create and manage different channels (e.g., general discussion, Q&A, resource sharing) with the following features:\n\t\t+ Channel creation: enable users to create new channels with customizable names and descriptions.\n\t\t+ Channel moderation: implement a system that allows channel administrators to moderate user posts and comments.\n3. **Message Input/Output Module**\n\t* Implement a message input system that allows users to type, paste, or share files using the following technologies:\n\t\t+ WebSockets for real-time communication between clients and servers.\n\t\t+ WebRTC for peer-to-peer file sharing.\n\n**II. Functional Modules**\n\n1. **Live Q&A Session Module**\n\t* Enable live Q&A sessions with AI-powered chatbots that provide real-time answers to user queries using the following features:\n\t\t+ Natural Language Processing (NLP) to understand user input.\n\t\t+ Machine Learning algorithms to improve chatbot responses over time.\n2. **Study Group Management Module**\n\t* Facilitate the creation of study groups, including group management tools (e.g., member list, group chat), with the following features:\n\t\t+ User roles: implement a system that allows administrators to assign user roles within study groups (e.g., leader, member).\n\t\t+ Task assignment: enable administrators to assign tasks and deadlines to group members.\n3. **Real-Time Feedback System Module**\n\t* Develop an AI-powered feedback system that provides users with instant feedback on their work using the following features:\n\t\t+ Automated scoring: implement a system that automatically scores user submissions based on predefined criteria.\n\t\t+ Personalized feedback: provide users with tailored feedback suggestions to improve their performance.\n\n**III. Integration Modules**\n\n1. **LMS Integration Module**\n\t* Integrate the Discord bot with popular LMS platforms (e.g., Canvas, Blackboard) using APIs and SDKs provided by these platforms.\n\t* Implement a system that allows administrators to map Discord channels to specific courses or modules in the LMS.\n2. **Resource Sharing Module**\n\t* Enable users to share resources (e.g., PDFs, images, audio files) between users using cloud storage services (e.g., Google Drive, Dropbox).\n\t* Implement a system that allows administrators to restrict access to shared resources based on user roles or permissions.\n3. **Analytics and Reporting Module**\n\t* Develop analytics tools to track system performance, user engagement, and study progress using the following metrics:\n\t\t+ User activity: track user login, channel participation, and message sent/received.\n\t\t+ Course engagement: monitor student progress and completion rates for each course.\n\t\t+ System performance: track bot uptime, error rates, and resource utilization.\n\n**IV. Security and Scalability**\n\n* Conduct regular security audits to identify vulnerabilities and implement patches as needed.\n* Develop a scalability plan that ensures the system can handle increasing user traffic and data storage needs.\n* Implement a caching layer to reduce load on servers and improve performance.\n\nThis refined version of the prompt addresses the weaknesses identified in the critique by providing more specific, actionable, and comprehensive requirements for each module. It also focuses on eliciting detailed information about implementation strategies, edge cases ...
# {'model': 'llama3.2:latest', 'prompt': "\n    Perform a detailed evaluation of the following requirement analysis response for an AI-powered Study Companion Discord Bot.\n    \n    Evaluate based on these specific criteria:\n    1. Clarity (1-10): Is the response well-structured, organized logically, and easy to understand?\n    2. Completeness (1-10): Does it thoroughly cover both functional and non-functional requirements?\n    3. Technical Accuracy (1-10): Are the statements factually correct and aligned with software engineering best practices?\n    4. Specificity (1-10): Does it provide concrete, actionable details rather than vague statements?\n    5. Feasibility (1-10): Are the requirements realistic and implementable?\n    \n    Response to evaluate:\n    Based on the refined prompt, I will provide a high-level overview of the proposed architecture and identify potential areas for improvement.\n\n**Overall Architecture**\n\nThe proposed Discord bot is designed to be modular, scalable, and secure. The system consists of four main components:\n\n1. Core Modules: These modules handle user management, channel creation/moderation, message input/output, live Q&A sessions, study group management, real-time feedback systems, LMS integration, resource sharing, analytics, and security.\n2. Functional Modules: These modules provide specific functionality for each feature mentioned in the prompt (e.g., natural language processing for chatbots).\n3. Integration Modules: These modules integrate with external services (LMS platforms, cloud storage providers) to enhance the bot's capabilities.\n4. Security and Scalability Module: This module ensures the system's security and scalability through regular audits, patching, caching, and performance monitoring.\n\n**Key Components**\n\n1. User Management Module:\n\t* Implement industry-standard protocols for user authentication (e.g., OAuth 2.0).\n\t* Use a robust password hashing algorithm to ensure data security.\n\t* Develop a user profile management system with features like notification updates.\n2. Channel Management Module:\n\t* Create channels with customizable names and descriptions.\n\t* Implement channel moderation using user roles and permissions.\n3. Message Input/Output Module:\n\t* Utilize WebSockets for real-time communication between clients and servers.\n\t* Leverage WebRTC for peer-to-peer file sharing.\n\n**Potential Areas for Improvement**\n\n1. **Security**: While regular security audits are mentioned, it's essential to consider the scope of these audits and ensure that they cover all areas of the system. Additionally, implement a bug bounty program to encourage responsible disclosure of vulnerabilities.\n2. **Scalability**: Plan for horizontal scaling (adding more servers) and vertical scaling (increasing server resources). Consider using containerization (e.g., Docker) to manage dependencies and improve performance.\n3. **Integration Complexity**: When integrating with external services, ensure that the implementation is modular, maintainable, and flexible. Use APIs and SDKs provided by these platforms to simplify interactions.\n4. **Performance Monitoring**: Implement a comprehensive monitoring system that tracks key metrics (e.g., CPU usage, memory allocation, network latency). This will help identify performance bottlenecks and optimize the system's resources.\n\n**Next Steps**\n\nTo further refine this architecture, I recommend:\n\n1. **Define technical requirements**: Break down each module into smaller, specific requirements, and prioritize them based on importance and complexity.\n2. **Develop a technology stack**: Choose a set of technologies that align with your requirements and are well-suited for the project's scope (e.g., Python, JavaScript, Docker).\n3. **Create a design document**: Outline the system's architecture, including high-level overviews, component interactions, and data flow.\n\nBy following these steps, you can create a more detailed, functi ...
# ✓ Refined prompt score: 424.80
#
# ==================================================
# OPTIMIZATION RESULTS
# ==================================================
# 🏆 Best Score: 424.80
# 📊 Metrics: {'word_count': 434, 'keyword_matches': 3, 'keyword_score': 30, 'ai_critique_score': 76.0, 'readability_score': 10, 'final_score': 424.8}
#
# ✅ BEST OPTIMIZED PROMPT:
# --------------------------------------------------
# Here is a refined version of the prompt, addressing the weaknesses identified in the critique:
#
# **Modular Architecture**
#
# **I. Core Modules**
#
# 1. **User Management Module**
# 	* Handle user registration, profile creation, and authentication using industry-standard protocols (e.g., OAuth 2.0).
# 	* Implement a robust password hashing algorithm to ensure data security.
# 	* Develop a user profile management system that allows users to update their information and set notifications for account updates.
# 2. **Channel Management Module**
# 	* Allow users to create and manage different channels (e.g., general discussion, Q&A, resource sharing) with the following features:
# 		+ Channel creation: enable users to create new channels with customizable names and descriptions.
# 		+ Channel moderation: implement a system that allows channel administrators to moderate user posts and comments.
# 3. **Message Input/Output Module**
# 	* Implement a message input system that allows users to type, paste, or share files using the following technologies:
# 		+ WebSockets for real-time communication between clients and servers.
# 		+ WebRTC for peer-to-peer file sharing.
#
# **II. Functional Modules**
#
# 1. **Live Q&A Session Module**
# 	* Enable live Q&A sessions with AI-powered chatbots that provide real-time answers to user queries using the following features:
# 		+ Natural Language Processing (NLP) to understand user input.
# 		+ Machine Learning algorithms to improve chatbot responses over time.
# 2. **Study Group Management Module**
# 	* Facilitate the creation of study groups, including group management tools (e.g., member list, group chat), with the following features:
# 		+ User roles: implement a system that allows administrators to assign user roles within study groups (e.g., leader, member).
# 		+ Task assignment: enable administrators to assign tasks and deadlines to group members.
# 3. **Real-Time Feedback System Module**
# 	* Develop an AI-powered feedback system that provides users with instant feedback on their work using the following features:
# 		+ Automated scoring: implement a system that automatically scores user submissions based on predefined criteria.
# 		+ Personalized feedback: provide users with tailored feedback suggestions to improve their performance.
#
# **III. Integration Modules**
#
# 1. **LMS Integration Module**
# 	* Integrate the Discord bot with popular LMS platforms (e.g., Canvas, Blackboard) using APIs and SDKs provided by these platforms.
# 	* Implement a system that allows administrators to map Discord channels to specific courses or modules in the LMS.
# 2. **Resource Sharing Module**
# 	* Enable users to share resources (e.g., PDFs, images, audio files) between users using cloud storage services (e.g., Google Drive, Dropbox).
# 	* Implement a system that allows administrators to restrict access to shared resources based on user roles or permissions.
# 3. **Analytics and Reporting Module**
# 	* Develop analytics tools to track system performance, user engagement, and study progress using the following metrics:
# 		+ User activity: track user login, channel participation, and message sent/received.
# 		+ Course engagement: monitor student progress and completion rates for each course.
# 		+ System performance: track bot uptime, error rates, and resource utilization.
#
# **IV. Security and Scalability**
#
# * Conduct regular security audits to identify vulnerabilities and implement patches as needed.
# * Develop a scalability plan that ensures the system can handle increasing user traffic and data storage needs.
# * Implement a caching layer to reduce load on servers and improve performance.
#
# This refined version of the prompt addresses the weaknesses identified in the critique by providing more specific, actionable, and comprehensive requirements for each module. It also focuses on eliciting detailed information about implementation strategies, edge cases, and technical accuracy.
# --------------------------------------------------
#
# 📜 GENERATED RESPONSE:
# --------------------------------------------------
# Based on the refined prompt, I will provide a high-level overview of the proposed architecture and identify potential areas for improvement.
#
# **Overall Architecture**
#
# The proposed Discord bot is designed to be modular, scalable, and secure. The system consists of four main components:
#
# 1. Core Modules: These modules handle user management, channel creation/moderation, message input/output, live Q&A sessions, study group management, real-time feedback systems, LMS integration, resource sharing, ...
# --------------------------------------------------
#
# 🔍 CRITIQUE:
# --------------------------------------------------
# Clarity: 8/10
# Explanation: The response is well-structured, but some sections feel a bit disconnected from each other. For example, the "Key Components" section jumps abruptly from discussing user management to channel management without providing clear connections between these components. Additionally, some technical terms (e.g., WebSockets, WebRTC) are used without prior explanation.
#
# Completeness: 7/10
# Explanation: The response covers many aspects of the system's architecture and requirements, but there are a few areas that feel underdeveloped or glossed over. For instance, the security section mentions regular audits but doesn't provide specific details on how these audits will be conducted or what tools will be used. Similarly, the performance monitoring section is mentioned briefly but lacks concrete recommendations for implementation.
#
# Technical Accuracy: 8/10
# Explanation: The response demonstrates a good understanding of software engineering principles and best practices. However, some statements feel speculative or based on general assumptions (e.g., the assumption that Docker will improve performance without providing specific evidence). Additionally, there are a few technical terms used without explanation (e.g., OAuth 2.0).
#
# Specificity: 6/10
# Explanation: While the response provides some concrete details about specific components and features, many of these statements feel vague or general. For example, the statement "utilize WebSockets for real-time communication" doesn't provide clear context or explain why this choice was made. Similarly, the recommendation to use a robust password hashing algorithm is a good start but lacks specificity on what algorithms are being considered.
#
# Feasibility: 7/10
# Explanation: The response demonstrates a reasonable understanding of the technical feasibility of the proposed system. However, some statements feel overly optimistic or assume that certain technologies will solve specific problems without providing evidence (e.g., the assumption that Docker will simplify integration with external services). Additionally, there are a few areas where the response could benefit from more concrete details on resource allocation and scalability.
#
# Overall: 7.6/10
# Explanation: While the response provides a solid foundation for understanding the proposed system's architecture and requirements, it could benefit from more specificity, concrete examples, and technical explanations to support its claims. Additionally, some areas feel underdeveloped or speculative, which may impact the overall feasibility of the project.
# ==================================================
