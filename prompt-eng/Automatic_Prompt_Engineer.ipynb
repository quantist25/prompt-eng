# %%
import json
import re
import time
import statistics
from _pipeline import create_payload, model_req

# Load previous best prompts with improved error handling
def load_prompt_history():
    try:
        with open("best_prompts.json", "r") as file:
            return json.load(file)
    except (FileNotFoundError, json.JSONDecodeError):
        print("Creating new prompt history database")
        return {}

# Enhanced domain-specific terminology with importance weights
important_terms = {
    "functional requirements": 15,
    "non-functional requirements": 15,
    "real-time study support": 10,
    "personalized tutoring": 10,
    "exam preparation": 10,
    "user experience": 12,
    "response time": 8,
    "scalability": 8,
    "security": 12,
    "integration": 10,
    "data privacy": 12,
    "accessibility": 10
}

def enhanced_score_response(response, metrics_only=False):
    """
    Enhanced scoring function with multiple evaluation dimensions
    Returns tuple: (final_score, detailed_metrics, critique)
    """
    # Initialize metrics dictionary
    metrics = {
        "word_count": len(response.split()),
        "keyword_matches": 0,
        "keyword_score": 0,
        "ai_critique_score": 0,
        "readability_score": 0
    }
    
    # Calculate keyword presence and weighted score
    for term, weight in important_terms.items():
        if term.lower() in response.lower():
            metrics["keyword_matches"] += 1
            metrics["keyword_score"] += weight
    
    # Simple readability metric (avg sentence length - prefer 15-20 words)
    sentences = [s.strip() for s in re.split(r'[.!?]', response) if s.strip()]
    if sentences:
        avg_sentence_length = statistics.mean([len(s.split()) for s in sentences])
        # Penalize sentences that are too short or too long
        if avg_sentence_length < 8:
            metrics["readability_score"] = 5
        elif avg_sentence_length > 30:
            metrics["readability_score"] = 6
        else:
            metrics["readability_score"] = 10
    
    # If only want metrics without AI critique (for faster iterations)
    if metrics_only:
        metrics["final_score"] = (
            metrics["word_count"] * 0.2 +
            metrics["keyword_score"] * 2 +
            metrics["readability_score"] * 5
        )
        return metrics["final_score"], metrics, "No critique requested"
        
    # AI-based multidimensional critique
    critic_prompt = f"""
    Perform a detailed evaluation of the following requirement analysis response for an AI-powered Study Companion Discord Bot.
    
    Evaluate based on these specific criteria:
    1. Clarity (1-10): Is the response well-structured, organized logically, and easy to understand?
    2. Completeness (1-10): Does it thoroughly cover both functional and non-functional requirements?
    3. Technical Accuracy (1-10): Are the statements factually correct and aligned with software engineering best practices?
    4. Specificity (1-10): Does it provide concrete, actionable details rather than vague statements?
    5. Feasibility (1-10): Are the requirements realistic and implementable?
    
    Response to evaluate:
    {response}
    
    Format your response exactly as follows:
    Clarity: [score]/10
    Completeness: [score]/10
    Technical Accuracy: [score]/10
    Specificity: [score]/10
    Feasibility: [score]/10
    Overall: [average score]/10
    
    Explanation: [brief justification for scores and specific improvement suggestions]
    """

    # Call the AI model to critique the response
    payload_critic = create_payload(
        target="ollama",
        model="llama3.2:latest",
        prompt=critic_prompt,
        temperature=0.4  # Lower temperature for more consistent evaluation
    )
    
    _, critic_feedback = model_req(payload_critic)
    
    # Extract all scores using regex
    scores = {}
    for criterion in ["Clarity", "Completeness", "Technical Accuracy", "Specificity", "Feasibility", "Overall"]:
        match = re.search(rf"{criterion}:\s*(\d+(?:\.\d+)?)/10", critic_feedback)
        if match:
            scores[criterion.lower()] = float(match.group(1))
    
    # Calculate average score if "Overall" wasn't extracted
    if "overall" not in scores and len(scores) > 0:
        scores["overall"] = sum(scores.values()) / len(scores)
    
    # Use overall score or default to 5
    critic_score = scores.get("overall", 5)
    metrics["ai_critique_score"] = critic_score * 10  # Scale to 0-100
    
    # Calculate final weighted score
    metrics["final_score"] = (
        metrics["word_count"] * 0.2 +           # 20% weight for length
        metrics["keyword_score"] * 2 +          # 40% weight for keywords
        metrics["ai_critique_score"] * 3 +      # 30% weight for AI critique
        metrics["readability_score"] * 5        # 10% weight for readability
    )
    
    return metrics["final_score"], metrics, critic_feedback

def generate_prompt_variations(base_prompt, n=3):
    """Generate multiple variations of a prompt to test effectiveness"""
    variation_prompt = f"""
    Create {n} variations of the following prompt. Each variation should maintain the same goal
    but experiment with different structures, emphasis, or approaches to potentially improve results.
    Make each variation distinctly different in structure or strategy.
    
    Original prompt:
    {base_prompt}
    
    Format your response as:
    VARIATION 1:
    [First complete prompt variation]
    
    VARIATION 2:
    [Second complete prompt variation]
    
    VARIATION 3:
    [Third complete prompt variation]
    """
    
    payload = create_payload(
        target="ollama",
        model="llama3.2:latest",
        prompt=variation_prompt,
        temperature=0.8,  # Higher temperature for more creative variations
        num_predict=2048
    )
    
    _, variations_text = model_req(payload)
    
    # Extract variations using regex
    variations = []
    for i in range(1, n+1):
        pattern = rf"VARIATION {i}:(.*?)(?:VARIATION {i+1}:|$)"
        match = re.search(pattern, variations_text, re.DOTALL)
        if match:
            variations.append(match.group(1).strip())
    
    # If extraction failed, fall back to simpler method
    if not variations:
        variations = [base_prompt]
        print("Failed to generate distinct variations")
    
    return variations

# Main optimization process
def optimize_prompt_pipeline():
    # Load prompt history at the beginning of the function
    prompt_history = load_prompt_history()
    
    # Step 1: Generate initial meta-prompt
    meta_prompt = (
        "Create a highly structured prompt that extracts detailed functional and non-functional "
        "requirements for an AI-powered Study Companion Discord Bot. The structured prompt should "
        "elicit comprehensive, technically precise, and actionable requirements spanning user "
        "interaction, performance criteria, security measures, and integration capabilities. "
        "Include specific sections for real-time study support, personalized tutoring, and exam preparation. "
        "The prompt should guide the response to be well-organized with clear categorization."
    )
    
    payload_meta = create_payload(
        target="ollama",
        model="llama3.2:latest",
        prompt=meta_prompt,
        temperature=0.7
    )
    _, base_prompt = model_req(payload_meta)
    print("✓ Generated base prompt")
    
    # Step 2: Generate multiple prompt variations
    prompt_variations = generate_prompt_variations(base_prompt, n=3)
    print(f"✓ Created {len(prompt_variations)} prompt variations")
    
    # Step 3: Test all variations
    results = []
    
    for i, prompt in enumerate(prompt_variations):
        print(f"Testing variation {i+1}...")
        
        # Execute prompt
        payload_exec = create_payload(
            target="ollama",
            model="llama3.2:latest",
            prompt=prompt,
            temperature=0.9,  # Slightly higher for creative requirements
            num_ctx=4096,
            num_predict=2048
        )
        _, response = model_req(payload_exec)
        
        # Score the response
        score, metrics, critique = enhanced_score_response(response)
        
        results.append({
            "prompt": prompt,
            "response": response,
            "score": score,
            "metrics": metrics,
            "critique": critique
        })
        
        print(f"  Score: {score:.2f}")
    
    # Sort by score (descending)
    results.sort(key=lambda x: x["score"], reverse=True)
    best_result = results[0]
    
    # Step 4: Refine the best prompt based on critique
    refinement_prompt = f"""
    Refine this prompt based on the following critique of the response it generated.
    
    Original prompt:
    {best_result["prompt"]}
    
    Response critique:
    {best_result["critique"]}
    
    Create an improved version of the prompt that addresses the weaknesses identified in the critique
    while maintaining its strengths. Focus especially on eliciting more specific, actionable, and
    comprehensive requirements.
    """
    
    payload_refine = create_payload(
        target="ollama",
        model="llama3.2:latest",
        prompt=refinement_prompt,
        temperature=0.6
    )
    _, refined_prompt = model_req(payload_refine)
    print("✓ Generated refined prompt")
    
    # Step 5: Test the refined prompt
    payload_refined_exec = create_payload(
        target="ollama",
        model="llama3.2:latest",
        prompt=refined_prompt,
        temperature=0.9,
        num_ctx=4096,
        num_predict=2048
    )
    _, refined_response = model_req(payload_refined_exec)
    
    refined_score, refined_metrics, refined_critique = enhanced_score_response(refined_response)
    print(f"✓ Refined prompt score: {refined_score:.2f}")
    
    # Step 6: Compare and select the best overall
    all_results = results + [{
        "prompt": refined_prompt,
        "response": refined_response,
        "score": refined_score,
        "metrics": refined_metrics,
        "critique": refined_critique
    }]
    
    all_results.sort(key=lambda x: x["score"], reverse=True)
    champion = all_results[0]
    
    # Save to history
    timestamp = time.strftime("%Y%m%d_%H%M%S")
    prompt_history[timestamp] = {
        "prompt": champion["prompt"],
        "score": champion["score"],
        "metrics": champion["metrics"]
    }
    
    # Save top 3 prompts to file
    with open("best_prompts.json", "w") as file:
        # Only store recent and high-scoring prompts (up to 20)
        if len(prompt_history) > 20:
            sorted_history = sorted(
                prompt_history.items(),
                key=lambda x: x[1].get("score", 0),
                reverse=True
            )
            prompt_history = dict(sorted_history[:20])
        
        json.dump(prompt_history, file, indent=4)
    
    # Output Results
    print("\n" + "="*50)
    print("OPTIMIZATION RESULTS")
    print("="*50)
    print(f"🏆 Best Score: {champion['score']:.2f}")
    print(f"📊 Metrics: {champion['metrics']}")
    print("\n✅ BEST OPTIMIZED PROMPT:")
    print("-"*50)
    print(champion["prompt"])
    print("-"*50)
    print("\n📜 GENERATED RESPONSE:")
    print("-"*50)
    print(champion["response"][:500] + "..." if len(champion["response"]) > 500 else champion["response"])
    print("-"*50)
    print("\n🔍 CRITIQUE:")
    print("-"*50)
    print(champion["critique"])
    print("="*50)
    
    return champion

# Run the optimization pipeline
if __name__ == "__main__":
    optimize_prompt_pipeline()
# Out:
# {'model': 'llama3.2:latest', 'prompt': 'Create a highly structured prompt that extracts detailed functional and non-functional requirements for an AI-powered Study Companion Discord Bot. The structured prompt should elicit comprehensive, technically precise, and actionable requirements spanning user interaction, performance criteria, security measures, and integration capabilities. Include specific sections for real-time study support, personalized tutoring, and exam preparation. The prompt should guide the response to be well-organized with clear categorization.', 'stream': False, 'options': {'temperature': 0.7}}
# ✓ Generated base prompt
# {'model': 'llama3.2:latest', 'prompt': "\n    Create 3 variations of the following prompt. Each variation should maintain the same goal\n    but experiment with different structures, emphasis, or approaches to potentially improve results.\n    Make each variation distinctly different in structure or strategy.\n    \n    Original prompt:\n    **AI-Powered Study Companion Discord Bot Requirements**\n\n**I. User Interaction Requirements**\n\n1. **User Registration and Authentication**\n\t* Users must create an account with a unique username and password.\n\t* Account creation process should include verification through email or phone number.\n\t* Users can log in using their registered credentials.\n2. **Chat Interface and Input Validation**\n\t* The chat interface should be user-friendly, with clear typography and minimal clutter.\n\t* Users must input text within a specific character limit (e.g., 500 characters).\n\t* Input validation should prevent users from posting excessively long or short messages.\n3. **Command Handling and Response Format**\n\t* The bot responds to user inputs in the format of pre-defined commands (e.g., `!help`, `!study`, etc.).\n\t* Bot responses should be concise, clear, and relevant to the user's query.\n\n**II. Real-Time Study Support Requirements**\n\n1. **Real-time Question Answering**\n\t* The bot must respond to user queries with relevant study materials (e.g., definitions, examples, etc.).\n\t* Response time should be ≤ 2 seconds for most queries.\n2. **Study Session Management**\n\t* Users can initiate a study session by specifying a topic or subject.\n\t* Bot will track the user's progress and provide real-time feedback during the session.\n3. **Real-time Feedback Mechanism**\n\t* The bot provides instant feedback on user answers, including correct/incorrect status and explanations.\n\n**III. Personalized Tutoring Requirements**\n\n1. **User Profiling and Learning Style Detection**\n\t* The bot creates a user profile based on their study habits, strengths, and weaknesses.\n\t* Bot detects the user's learning style (e.g., visual, auditory, kinesthetic).\n2. **Personalized Study Plan Generation**\n\t* Based on the user profile and learning style, generate a personalized study plan with specific objectives and timelines.\n3. **Adaptive Difficulty Adjustment**\n\t* The bot adjusts the difficulty level of study materials based on the user's performance.\n\n**IV. Exam Preparation Requirements**\n\n1. **Mock Test Generation**\n\t* The bot generates mock tests based on the user's profiled strengths and weaknesses.\n2. **Exam Simulation Mode**\n\t* Users can opt for exam simulation mode, where the bot simulates a real-time test environment with time limits and scoring.\n3. **Score Analysis and Feedback**\n\t* The bot provides detailed score analysis and feedback to help users identify areas of improvement.\n\n**V. Performance Criteria Requirements**\n\n1. **Response Time and Latency**\n\t* Response time should be ≤ 500ms for most queries.\n2. **Accuracy and Reliability**\n\t* Bot accuracy rate should be ≥ 95% for real-time question answering.\n3. **Scalability and Load Handling**\n\t* The bot can handle a minimum of 100 concurrent users without significant degradation in performance.\n\n**VI. Security Measures Requirements**\n\n1. **Data Encryption**\n\t* All user data, including chat logs and study materials, should be encrypted using industry-standard protocols (e.g., SSL/TLS).\n2. **Access Control and Permissions**\n\t* Users can only access their own study materials and chat history.\n3. **Regular Backups and Data Recovery**\n\t* The bot performs daily backups of all data and ensures data recovery in case of failure.\n\n**VII. Integration Capabilities Requirements**\n\n1. **API Integration with Learning Platforms**\n\t* The bot integrates with popular learning platforms (e.g., Coursera, Udemy) to retrieve relevant study materials.\n2. **Social Media Sharing**\n\t* Users can share their study progr ...
# ✓ Created 3 prompt variations
# Testing variation 1...
# {'model': 'llama3.2:latest', 'prompt': 'Streamlined and Concise Requirements**\n\nI. User Interaction Requirements\n\n* **Registration and Authentication**\n\t+ Unique username and password creation with email/phone verification\n\t+ Secure login system for user credentials\n* **Chat Interface and Input Validation**\n\t+ User-friendly chat interface with clear typography and minimal clutter\n\t+ Character limit of 500 characters for input validation\n* **Command Handling and Response Format**\n\t+ Pre-defined command responses (e.g., !help, !study)\n\t+ Concise and relevant responses within ≤ 2 seconds\n\nII. Real-Time Study Support Requirements\n\n* **Question Answering**\n\t+ Relevant study materials in response to user queries\n\t+ ≤ 2-second response time for most queries\n* **Study Session Management**\n\t+ User-initiated study sessions with topic or subject specification\n\t+ Real-time feedback and progress tracking during sessions\n* **Real-Time Feedback Mechanism**\n\t+ Instant feedback on user answers, including correct/incorrect status and explanations\n\nIII. Personalized Tutoring Requirements\n\n* **User Profiling and Learning Style Detection**\n\t+ User profile creation based on study habits, strengths, and weaknesses\n\t+ Learning style detection (e.g., visual, auditory, kinesthetic)\n* **Personalized Study Plan Generation**\n\t+ Customized study plan with specific objectives and timelines\n* **Adaptive Difficulty Adjustment**\n\t+ Bot adjusts difficulty level of study materials based on user performance\n\nIV. Exam Preparation Requirements\n\n* **Mock Test Generation**\n\t+ Mock tests tailored to user profiled strengths and weaknesses\n* **Exam Simulation Mode**\n\t+ Real-time test environment with time limits and scoring\n* **Score Analysis and Feedback**\n\t+ Detailed score analysis and feedback for improved understanding\n\nV. Performance Criteria Requirements\n\n* **Response Time and Latency**\n\t+ ≤ 500ms response time for most queries\n* **Accuracy and Reliability**\n\t+ ≥ 95% accuracy rate for real-time question answering\n* **Scalability and Load Handling**\n\t+ Ability to handle ≤ 100 concurrent users without performance degradation\n\nVI. Security Measures Requirements\n\n* **Data Encryption**\n\t+ Industry-standard encryption protocols (e.g., SSL/TLS) for user data protection\n* **Access Control and Permissions**\n\t+ Secure access to user data, chat logs, and study materials\n* **Regular Backups and Data Recovery**\n\t+ Daily backups of all data with secure data recovery mechanisms\n\nVII. Integration Capabilities Requirements\n\n* **API Integration with Learning Platforms**\n\t+ Integration with popular learning platforms (e.g., Coursera, Udemy) for relevant study materials\n* **Social Media Sharing**\n\t+ Users can share their study progress and achievements on social media platforms\n* **Third-Party Integration for Additional Features**\n\t+ Integration with third-party services for features like calendar management or task assignments\n\nVIII. Technical Requirements\n\n* **Programming Language and Framework**\n\t+ Suitable programming language (e.g., Python) and framework (e.g., Discord.py)\n* **Database Management System**\n\t+ Reliable database management system (e.g., MySQL) for user data storage\n* **Server Infrastructure**\n\t+ Sufficient RAM, CPU power, and storage capacity for optimal performance\n\nIX. Non-Functional Requirements\n\n* **Usability and Accessibility**\n\t+ Clear typography, minimal clutter, and accessible navigation for an engaging experience\n* **User Experience (UX) and User Interface (UI)**\n\t+ Engaging UX/UI that responds to user inputs with ease\n\n**', 'stream': False, 'options': {'temperature': 0.9, 'num_ctx': 4096, 'num_predict': 2048}}
# {'model': 'llama3.2:latest', 'prompt': "\n    Perform a detailed evaluation of the following requirement analysis response for an AI-powered Study Companion Discord Bot.\n    \n    Evaluate based on these specific criteria:\n    1. Clarity (1-10): Is the response well-structured, organized logically, and easy to understand?\n    2. Completeness (1-10): Does it thoroughly cover both functional and non-functional requirements?\n    3. Technical Accuracy (1-10): Are the statements factually correct and aligned with software engineering best practices?\n    4. Specificity (1-10): Does it provide concrete, actionable details rather than vague statements?\n    5. Feasibility (1-10): Are the requirements realistic and implementable?\n    \n    Response to evaluate:\n    This is a comprehensive set of requirements for building a study support platform. Here's a condensed version of the key points:\n\nI. User Interaction Requirements\n\n* Secure login system\n* User-friendly chat interface with character limit and clear typography\n* Pre-defined command responses (e.g., !help, !study)\n* Concise and relevant responses within 2 seconds\n\nII. Real-Time Study Support Requirements\n\n* Relevant study materials for user queries\n* User-initiated study sessions with real-time feedback and progress tracking\n* Instant feedback on user answers, including correct/incorrect status and explanations\n\nIII. Personalized Tutoring Requirements\n\n* User profiling and learning style detection\n* Customized study plan generation\n* Adaptive difficulty adjustment based on user performance\n\nIV. Exam Preparation Requirements\n\n* Mock test generation tailored to user profiled strengths and weaknesses\n* Real-time test environment with time limits and scoring\n* Detailed score analysis and feedback for improved understanding\n\nV. Performance Criteria Requirements\n\n* ≤ 500ms response time for most queries\n* ≥ 95% accuracy rate for real-time question answering\n* Ability to handle up to 100 concurrent users without performance degradation\n\nVI. Security Measures Requirements\n\n* Industry-standard encryption protocols (e.g., SSL/TLS) for user data protection\n* Secure access to user data, chat logs, and study materials\n* Daily backups of all data with secure data recovery mechanisms\n\nVII. Integration Capabilities Requirements\n\n* API integration with popular learning platforms\n* Social media sharing functionality\n* Third-party integration for additional features\n\nVIII. Technical Requirements\n\n* Suitable programming language (e.g., Python) and framework (e.g., Discord.py)\n* Reliable database management system (e.g., MySQL)\n\nIX. Non-Functional Requirements\n\n* Engaging UX/UI that responds to user inputs with ease\n* Clear typography, minimal clutter for an engaging experience\n    \n    Format your response exactly as follows:\n    Clarity: [score]/10\n    Completeness: [score]/10\n    Technical Accuracy: [score]/10\n    Specificity: [score]/10\n    Feasibility: [score]/10\n    Overall: [average score]/10\n    \n    Explanation: [brief justification for scores and specific improvement suggestions]\n    ", 'stream': False, 'options': {'temperature': 0.4}}
#   Score: 519.40
# Testing variation 2...
# {'model': 'llama3.2:latest', 'prompt': "Expanded Functional Requirements**\n\nI. User Interaction Requirements\n\n* **Registration and Authentication**\n\t+ Additional security measures, such as two-factor authentication or biometric login\n\t+ Customizable account creation process for users' preferences\n* **Chat Interface and Input Validation**\n\t+ Character limit of 1000 characters for input validation\n\t+ Integration with voice-to-text functionality for users with disabilities\n* **Command Handling and Response Format**\n\t+ Support for multiple command formats (e.g., !, @, etc.)\n\t+ Ability to respond in natural language format\n\nII. Real-Time Study Support Requirements\n\n* **Question Answering**\n\t+ Additional question types, such as image or audio-based questions\n\t+ Integration with popular study aids, like flashcards or concept maps\n* **Study Session Management**\n\t+ Customizable study session length and schedule\n\t+ Option for users to invite friends or classmates to join their sessions\n* **Real-Time Feedback Mechanism**\n\t+ Explanation of incorrect answers, including step-by-step analysis\n\t+ Ability to track progress and provide insights on strengths and weaknesses\n\nIII. Personalized Tutoring Requirements\n\n* **User Profiling and Learning Style Detection**\n\t+ Integration with popular learning style assessments (e.g., VARK, MBTI)\n\t+ Customizable user profile based on individual learning preferences\n* **Personalized Study Plan Generation**\n\t+ Ability to generate study plans for specific exams or subjects\n\t+ Option for users to add personal goals and objectives to their study plan\n* **Adaptive Difficulty Adjustment**\n\t+ Integration with adaptive technology, such as AI-powered difficulty adjusters\n\nIV. Exam Preparation Requirements\n\n* **Mock Test Generation**\n\t+ Customizable mock test formats, including timed or untimed questions\n\t+ Option for users to review and analyze their test results in detail\n* **Exam Simulation Mode**\n\t+ Integration with popular testing software (e.g., Prometric, Pearson VUE)\n\t+ Ability to simulate real-world exam conditions, including time pressure and distractions\n* **Score Analysis and Feedback**\n\t+ Comprehensive score analysis, including detailed feedback on strengths and weaknesses\n\t+ Option for users to review and adjust their study plan based on their performance\n\nV. Performance Criteria Requirements\n\n* **Response Time and Latency**\n\t+ ≤ 200ms response time for most queries during peak hours\n\t+ Ability to handle up to 500 concurrent users without performance degradation\n* **Accuracy and Reliability**\n\t+ ≥ 98% accuracy rate for real-time question answering\n\t+ Integration with multiple data sources for increased reliability\n* **Scalability and Load Handling**\n\t+ Ability to scale up or down based on user demand, ensuring optimal performance\n\nVI. Security Measures Requirements\n\n* **Data Encryption**\n\t+ Additional security measures, such as encryption at rest and in transit\n\t+ Regular security audits and penetration testing\n* **Access Control and Permissions**\n\t+ Customizable access control for users, including role-based permissions\n\t+ Integration with Single Sign-On (SSO) systems for secure login\n\nVII. Integration Capabilities Requirements\n\n* **API Integration with Learning Platforms**\n\t+ Integration with multiple learning platforms, including MOOCs and online courses\n\t+ Ability to sync user data across different platforms\n* **Social Media Sharing**\n\t+ Customizable social media sharing options, including text, image, and video sharing\n\t+ Option for users to share their study progress and achievements on multiple platforms\n* **Third-Party Integration for Additional Features**\n\t+ Integration with popular productivity tools (e.g., Todoist, Trello)\n\t+ Ability to integrate with wearable devices or health trackers\n\nVIII. Technical Requirements\n\n* **Programming Language and Framework**\n\t+ Support for ...
# {'model': 'llama3.2:latest', 'prompt': "\n    Perform a detailed evaluation of the following requirement analysis response for an AI-powered Study Companion Discord Bot.\n    \n    Evaluate based on these specific criteria:\n    1. Clarity (1-10): Is the response well-structured, organized logically, and easy to understand?\n    2. Completeness (1-10): Does it thoroughly cover both functional and non-functional requirements?\n    3. Technical Accuracy (1-10): Are the statements factually correct and aligned with software engineering best practices?\n    4. Specificity (1-10): Does it provide concrete, actionable details rather than vague statements?\n    5. Feasibility (1-10): Are the requirements realistic and implementable?\n    \n    Response to evaluate:\n    Here is a summary of the expanded functional requirements:\n\n**I. User Interaction Requirements**\n\n* Additional security measures for registration and authentication\n* Customizable account creation process\n* Character limit of 1000 characters for input validation\n* Integration with voice-to-text functionality for users with disabilities\n\n**II. Real-Time Study Support Requirements**\n\n* Additional question types, such as image or audio-based questions\n* Integration with popular study aids, like flashcards or concept maps\n* Customizable study session length and schedule\n* Option for users to invite friends or classmates to join their sessions\n* Real-time feedback mechanism with explanation of incorrect answers\n\n**III. Personalized Tutoring Requirements**\n\n* User profiling and learning style detection\n* Integration with popular learning style assessments\n* Customizable user profile based on individual learning preferences\n* Personalized study plan generation\n* Adaptive difficulty adjustment\n\n**IV. Exam Preparation Requirements**\n\n* Customizable mock test formats, including timed or untimed questions\n* Option for users to review and analyze their test results in detail\n* Integration with popular testing software\n* Ability to simulate real-world exam conditions\n* Comprehensive score analysis and feedback\n\n**V. Performance Criteria Requirements**\n\n* Response time and latency: ≤ 200ms during peak hours\n* Accuracy and reliability: ≥ 98% accuracy rate for real-time question answering\n* Scalability and load handling: ability to handle up to 500 concurrent users without performance degradation\n\n**VI. Security Measures Requirements**\n\n* Data encryption at rest and in transit\n* Regular security audits and penetration testing\n* Customizable access control for users, including role-based permissions\n* Integration with Single Sign-On (SSO) systems for secure login\n\n**VII. Integration Capabilities Requirements**\n\n* API integration with multiple learning platforms\n* Social media sharing options\n* Third-party integration for additional features with popular productivity tools and wearable devices\n\n**VIII. Technical Requirements**\n\n* Support for multiple programming languages, including Python, Java, and C#\n* Customizable framework based on user preferences\n* Integration with cloud-based databases\n* Customizable server infrastructure based on user needs\n\n**IX. Non-Functional Requirements**\n\n* Usability and accessibility: integration with accessibility features and adaptable design\n* User experience (UX) and user interface (UI): customizable UI and integration with popular UX design tools.\n\nThis expanded functional requirements document provides a detailed overview of the system's capabilities, security measures, performance criteria, technical requirements, and non-functional requirements. It ensures that the development team has a comprehensive understanding of the system's requirements and can deliver a high-quality solution that meets user needs and expectations.\n    \n    Format your response exactly as follows:\n    Clarity: [score]/10\n    Completeness: [score]/10\n    Technical Accuracy: [score]/10\n    Specificity: [s ...
#   Score: 599.60
# Testing variation 3...
# {'model': 'llama3.2:latest', 'prompt': 'Comprehensive Non-Functional Requirements**\n\nI. Usability and Accessibility\n\n* **Accessibility Features**\n\t+ Integration with accessibility features, such as screen readers and high contrast mode\n\t+ Customizable font sizes and colors for users with visual impairments\n* **Screen Size Adaptation**\n\t+ Ability to adapt to different screen sizes, from smartphones to desktops\n\t+ Customizable layout based on user preferences\n\nII. User Experience (UX) and User Interface (UI)\n\n* **Customizable UI**\n\t+ Option for users to customize their dashboard, including widgets and layouts\n\t+ Ability to add or remove features as needed\n* **Feedback Mechanism**\n\t+ Integration with feedback mechanisms, such as surveys and ratings systems\n\t+ Customizable feedback options based on user preferences\n\nIII. Performance Requirements\n\n* **Responsiveness**\n\t+ Ability to respond quickly to user input, even during peak hours\n\t+ Customizable response time based on user preferences\n* **Stability and Reliability**\n\t+ Integration with redundancy measures, such as backup servers and load balancers\n\t+ Regular performance audits to ensure optimal stability\n\nIV. Security Requirements\n\n* **Data Protection**\n\t+ Additional security measures, such as encryption at rest and in transit\n\t+ Regular data protection audits and compliance checks\n* **Compliance**\n\t+ Integration with regulatory requirements, such as GDPR and HIPAA\n\t+ Customizable compliance options based on user preferences\n\nV. Support Requirements\n\n* **Technical Support**\n\t+ Integration with technical support systems, such as ticketing software and knowledge bases\n\t+ Customizable support options based on user preferences\n* **Customer Service**\n\t+ Option for users to communicate directly with customer support teams\n\t+ Ability to schedule regular check-ins and support sessions\n\nVI. Integration Requirements\n\n* **API Integration**\n\t+ Integration with multiple APIs, including third', 'stream': False, 'options': {'temperature': 0.9, 'num_ctx': 4096, 'num_predict': 2048}}
# {'model': 'llama3.2:latest', 'prompt': "\n    Perform a detailed evaluation of the following requirement analysis response for an AI-powered Study Companion Discord Bot.\n    \n    Evaluate based on these specific criteria:\n    1. Clarity (1-10): Is the response well-structured, organized logically, and easy to understand?\n    2. Completeness (1-10): Does it thoroughly cover both functional and non-functional requirements?\n    3. Technical Accuracy (1-10): Are the statements factually correct and aligned with software engineering best practices?\n    4. Specificity (1-10): Does it provide concrete, actionable details rather than vague statements?\n    5. Feasibility (1-10): Are the requirements realistic and implementable?\n    \n    Response to evaluate:\n    Based on the provided comprehensive non-functional requirements document, I'll summarize the key points in a concise format for easy reference:\n\n**Non-Functional Requirements**\n\n1. **Usability and Accessibility**\n\t* Accessibility features (integration with screen readers, high contrast mode, customizable font sizes and colors)\n\t* Screen size adaptation (adapt to different screen sizes, customizable layout based on user preferences)\n\n2. **User Experience (UX) and User Interface (UI)**\n\t* Customizable UI (option for users to customize dashboard, widgets, and layouts)\n\t* Feedback mechanism (integration with surveys and ratings systems, customizable feedback options)\n\n3. **Performance Requirements**\n\t* Responsiveness (ability to respond quickly to user input, customizable response time based on user preferences)\n\t* Stability and reliability (integration with redundancy measures, regular performance audits)\n\n4. **Security Requirements**\n\t* Data protection (additional security measures like encryption at rest and in transit, regular data protection audits)\n\t* Compliance (integration with regulatory requirements, customizable compliance options)\n\n5. **Support Requirements**\n\t* Technical support (integration with technical support systems, customizable support options)\n\t* Customer service (option for users to communicate directly with customer support teams, ability to schedule regular check-ins and support sessions)\n\n6. **Integration Requirements**\n\t* API integration (integration with multiple APIs, including third-party services)\n    \n    Format your response exactly as follows:\n    Clarity: [score]/10\n    Completeness: [score]/10\n    Technical Accuracy: [score]/10\n    Specificity: [score]/10\n    Feasibility: [score]/10\n    Overall: [average score]/10\n    \n    Explanation: [brief justification for scores and specific improvement suggestions]\n    ", 'stream': False, 'options': {'temperature': 0.4}}
#   Score: 499.00
# {'model': 'llama3.2:latest', 'prompt': "\n    Refine this prompt based on the following critique of the response it generated.\n    \n    Original prompt:\n    Expanded Functional Requirements**\n\nI. User Interaction Requirements\n\n* **Registration and Authentication**\n\t+ Additional security measures, such as two-factor authentication or biometric login\n\t+ Customizable account creation process for users' preferences\n* **Chat Interface and Input Validation**\n\t+ Character limit of 1000 characters for input validation\n\t+ Integration with voice-to-text functionality for users with disabilities\n* **Command Handling and Response Format**\n\t+ Support for multiple command formats (e.g., !, @, etc.)\n\t+ Ability to respond in natural language format\n\nII. Real-Time Study Support Requirements\n\n* **Question Answering**\n\t+ Additional question types, such as image or audio-based questions\n\t+ Integration with popular study aids, like flashcards or concept maps\n* **Study Session Management**\n\t+ Customizable study session length and schedule\n\t+ Option for users to invite friends or classmates to join their sessions\n* **Real-Time Feedback Mechanism**\n\t+ Explanation of incorrect answers, including step-by-step analysis\n\t+ Ability to track progress and provide insights on strengths and weaknesses\n\nIII. Personalized Tutoring Requirements\n\n* **User Profiling and Learning Style Detection**\n\t+ Integration with popular learning style assessments (e.g., VARK, MBTI)\n\t+ Customizable user profile based on individual learning preferences\n* **Personalized Study Plan Generation**\n\t+ Ability to generate study plans for specific exams or subjects\n\t+ Option for users to add personal goals and objectives to their study plan\n* **Adaptive Difficulty Adjustment**\n\t+ Integration with adaptive technology, such as AI-powered difficulty adjusters\n\nIV. Exam Preparation Requirements\n\n* **Mock Test Generation**\n\t+ Customizable mock test formats, including timed or untimed questions\n\t+ Option for users to review and analyze their test results in detail\n* **Exam Simulation Mode**\n\t+ Integration with popular testing software (e.g., Prometric, Pearson VUE)\n\t+ Ability to simulate real-world exam conditions, including time pressure and distractions\n* **Score Analysis and Feedback**\n\t+ Comprehensive score analysis, including detailed feedback on strengths and weaknesses\n\t+ Option for users to review and adjust their study plan based on their performance\n\nV. Performance Criteria Requirements\n\n* **Response Time and Latency**\n\t+ ≤ 200ms response time for most queries during peak hours\n\t+ Ability to handle up to 500 concurrent users without performance degradation\n* **Accuracy and Reliability**\n\t+ ≥ 98% accuracy rate for real-time question answering\n\t+ Integration with multiple data sources for increased reliability\n* **Scalability and Load Handling**\n\t+ Ability to scale up or down based on user demand, ensuring optimal performance\n\nVI. Security Measures Requirements\n\n* **Data Encryption**\n\t+ Additional security measures, such as encryption at rest and in transit\n\t+ Regular security audits and penetration testing\n* **Access Control and Permissions**\n\t+ Customizable access control for users, including role-based permissions\n\t+ Integration with Single Sign-On (SSO) systems for secure login\n\nVII. Integration Capabilities Requirements\n\n* **API Integration with Learning Platforms**\n\t+ Integration with multiple learning platforms, including MOOCs and online courses\n\t+ Ability to sync user data across different platforms\n* **Social Media Sharing**\n\t+ Customizable social media sharing options, including text, image, and video sharing\n\t+ Option for users to share their study progress and achievements on multiple platforms\n* **Third-Party Integration for Additional Features**\n\t+ Integration with popular productivity tools (e.g., Todoist, Trello)\n\t+ Ability to integrate with wearable ...
# ✓ Generated refined prompt
# {'model': 'llama3.2:latest', 'prompt': 'Expanded Functional Requirements Document: AI-Powered Study Companion Discord Bot\n\nI. User Interaction Requirements\n\n* **Registration and Authentication**\n\t+ Implement a custom registration process that includes:\n\t\t- A unique username generation algorithm\n\t\t- A minimum of 8-character password requirement with a complexity score (e.g., uppercase, lowercase, numbers, special characters)\n\t\t- Additional security measures, such as two-factor authentication or biometric login, for an optional premium subscription tier\n* **Chat Interface and Input Validation**\n\t+ Implement the following input validation rules:\n\t\t- Character limit of 1000 characters for text input\n\t\t- Integer limits for numerical inputs (e.g., exam scores, study hours)\n\t\t- Integration with voice-to-text functionality for users with disabilities, including support for multiple languages\n* **Command Handling and Response Format**\n\t+ Develop a command handling system that supports:\n\t\t- Multiple command formats (e.g., !, @, etc.)\n\t\t- Natural language responses using a combination of machine learning algorithms and natural language processing techniques\n\nII. Real-Time Study Support Requirements\n\n* **Question Answering**\n\t+ Integrate with popular study aids, such as flashcards or concept maps, to provide:\n\t\t- Image-based question types (e.g., multiple-choice with images)\n\t\t- Audio-based question types (e.g., audio clips with accompanying questions)\n\t+ Implement an adaptive difficulty adjustment system that adjusts the difficulty level based on user performance\n* **Study Session Management**\n\t+ Develop a customizable study session length and schedule feature, allowing users to:\n\t\t- Set recurring sessions for regular study practice\n\t\t- Schedule sessions at specific times of the day or week\n\t+ Implement an option for users to invite friends or classmates to join their study sessions\n* **Real-Time Feedback Mechanism**\n\t+ Provide an explanation of incorrect answers, including step-by-step analysis and suggestions for improvement\n\t+ Track user progress and provide insights on strengths and weaknesses through:\n\t\t- A comprehensive dashboard with key performance indicators (KPIs)\n\t\t- Personalized recommendations for improvement\n\nIII. Personalized Tutoring Requirements\n\n* **User Profiling and Learning Style Detection**\n\t+ Integrate with popular learning style assessments, such as VARK or MBTI\n\t+ Implement a customizable user profile that takes into account individual learning preferences\n* **Personalized Study Plan Generation**\n\t+ Develop an algorithm that generates a personalized study plan for specific exams or subjects, including:\n\t\t- Customizable goals and objectives\n\t\t- Suggested study materials and resources\n\t+ Allow users to add personal notes and comments to their study plans\n\nIV. Exam Preparation Requirements\n\n* **Mock Test Generation**\n\t+ Develop a comprehensive mock test system that includes:\n\t\t- A variety of question types (e.g., multiple-choice, true/false, fill-in-the-blank)\n\t\t- Timed and untimed modes\n\t\t- Option to record and review study sessions\n* **Testing Software Integration**\n\t+ Integrate with popular testing software, such as Prometric or Pearson VUE, to provide:\n\t\t- Compatibility with existing test formats (e.g., multiple-choice, essay questions)\n\t\t- Support for additional features (e.g., adaptive scoring, test analytics)\n\nV. Technical Requirements\n\n* **Cloud-Based Database Integration**\n\t+ Integrate a cloud-based database service (e.g., AWS Amplify, Google Cloud Firestore) to store user data and study materials\n\t+ Implement robust security measures to protect user data, including encryption and access controls\n* **Machine Learning Algorithm Development**\n\t+ Develop and train machine learning algorithms for natural language processing, question answering, and personalized tutoring\n\nVI. Non-Functi ...
# {'model': 'llama3.2:latest', 'prompt': "\n    Perform a detailed evaluation of the following requirement analysis response for an AI-powered Study Companion Discord Bot.\n    \n    Evaluate based on these specific criteria:\n    1. Clarity (1-10): Is the response well-structured, organized logically, and easy to understand?\n    2. Completeness (1-10): Does it thoroughly cover both functional and non-functional requirements?\n    3. Technical Accuracy (1-10): Are the statements factually correct and aligned with software engineering best practices?\n    4. Specificity (1-10): Does it provide concrete, actionable details rather than vague statements?\n    5. Feasibility (1-10): Are the requirements realistic and implementable?\n    \n    Response to evaluate:\n    This is a comprehensive Functional Requirements Document (FRD) for an AI-Powered Study Companion Discord Bot. It outlines the functional and non-functional requirements for the bot's development.\n\nI. User Interaction Requirements:\n\nThe FRD covers various aspects of user interaction, including registration and authentication, chat interface and input validation, command handling and response format, question answering, study session management, real-time feedback mechanism, personalized tutoring, and exam preparation.\n\nII. Real-Time Study Support Requirements:\n\nThis section focuses on the bot's capabilities for supporting users in their studies, including image-based question types, audio-based question types, adaptive difficulty adjustment, customizable study sessions, and real-time feedback mechanisms.\n\nIII. Personalized Tutoring Requirements:\n\nThe FRD addresses the bot's personalized tutoring capabilities, such as user profiling, learning style detection, personalized study plan generation, and customizable goals and objectives.\n\nIV. Exam Preparation Requirements:\n\nThis section outlines the bot's features for exam preparation, including mock test generation, testing software integration, compatibility with existing test formats, and support for additional features like adaptive scoring and test analytics.\n\nV. Technical Requirements:\n\nThe FRD covers technical requirements such as cloud-based database integration, machine learning algorithm development, scalability and performance, security and compliance, and other technical considerations.\n\nVI. Non-Functional Requirements:\n\nThis section highlights the non-functional requirements of the bot, including its ability to handle a large number of concurrent users without significant degradation in performance, ensuring robust security measures to protect user data, and complying with relevant regulations.\n\nThe FRD provides a solid foundation for the development of an AI-Powered Study Companion Discord Bot that addresses various aspects of user interaction, study support, personalized tutoring, exam preparation, technical requirements, and non-functional considerations.\n    \n    Format your response exactly as follows:\n    Clarity: [score]/10\n    Completeness: [score]/10\n    Technical Accuracy: [score]/10\n    Specificity: [score]/10\n    Feasibility: [score]/10\n    Overall: [average score]/10\n    \n    Explanation: [brief justification for scores and specific improvement suggestions]\n    ", 'stream': False, 'options': {'temperature': 0.4}}
# ✓ Refined prompt score: 520.20
#
# ==================================================
# OPTIMIZATION RESULTS
# ==================================================
# 🏆 Best Score: 599.60
# 📊 Metrics: {'word_count': 403, 'keyword_matches': 11, 'keyword_score': 120, 'ai_critique_score': 83.0, 'readability_score': 6, 'final_score': 599.6}
#
# ✅ BEST OPTIMIZED PROMPT:
# --------------------------------------------------
# Expanded Functional Requirements**
#
# I. User Interaction Requirements
#
# * **Registration and Authentication**
# 	+ Additional security measures, such as two-factor authentication or biometric login
# 	+ Customizable account creation process for users' preferences
# * **Chat Interface and Input Validation**
# 	+ Character limit of 1000 characters for input validation
# 	+ Integration with voice-to-text functionality for users with disabilities
# * **Command Handling and Response Format**
# 	+ Support for multiple command formats (e.g., !, @, etc.)
# 	+ Ability to respond in natural language format
#
# II. Real-Time Study Support Requirements
#
# * **Question Answering**
# 	+ Additional question types, such as image or audio-based questions
# 	+ Integration with popular study aids, like flashcards or concept maps
# * **Study Session Management**
# 	+ Customizable study session length and schedule
# 	+ Option for users to invite friends or classmates to join their sessions
# * **Real-Time Feedback Mechanism**
# 	+ Explanation of incorrect answers, including step-by-step analysis
# 	+ Ability to track progress and provide insights on strengths and weaknesses
#
# III. Personalized Tutoring Requirements
#
# * **User Profiling and Learning Style Detection**
# 	+ Integration with popular learning style assessments (e.g., VARK, MBTI)
# 	+ Customizable user profile based on individual learning preferences
# * **Personalized Study Plan Generation**
# 	+ Ability to generate study plans for specific exams or subjects
# 	+ Option for users to add personal goals and objectives to their study plan
# * **Adaptive Difficulty Adjustment**
# 	+ Integration with adaptive technology, such as AI-powered difficulty adjusters
#
# IV. Exam Preparation Requirements
#
# * **Mock Test Generation**
# 	+ Customizable mock test formats, including timed or untimed questions
# 	+ Option for users to review and analyze their test results in detail
# * **Exam Simulation Mode**
# 	+ Integration with popular testing software (e.g., Prometric, Pearson VUE)
# 	+ Ability to simulate real-world exam conditions, including time pressure and distractions
# * **Score Analysis and Feedback**
# 	+ Comprehensive score analysis, including detailed feedback on strengths and weaknesses
# 	+ Option for users to review and adjust their study plan based on their performance
#
# V. Performance Criteria Requirements
#
# * **Response Time and Latency**
# 	+ ≤ 200ms response time for most queries during peak hours
# 	+ Ability to handle up to 500 concurrent users without performance degradation
# * **Accuracy and Reliability**
# 	+ ≥ 98% accuracy rate for real-time question answering
# 	+ Integration with multiple data sources for increased reliability
# * **Scalability and Load Handling**
# 	+ Ability to scale up or down based on user demand, ensuring optimal performance
#
# VI. Security Measures Requirements
#
# * **Data Encryption**
# 	+ Additional security measures, such as encryption at rest and in transit
# 	+ Regular security audits and penetration testing
# * **Access Control and Permissions**
# 	+ Customizable access control for users, including role-based permissions
# 	+ Integration with Single Sign-On (SSO) systems for secure login
#
# VII. Integration Capabilities Requirements
#
# * **API Integration with Learning Platforms**
# 	+ Integration with multiple learning platforms, including MOOCs and online courses
# 	+ Ability to sync user data across different platforms
# * **Social Media Sharing**
# 	+ Customizable social media sharing options, including text, image, and video sharing
# 	+ Option for users to share their study progress and achievements on multiple platforms
# * **Third-Party Integration for Additional Features**
# 	+ Integration with popular productivity tools (e.g., Todoist, Trello)
# 	+ Ability to integrate with wearable devices or health trackers
#
# VIII. Technical Requirements
#
# * **Programming Language and Framework**
# 	+ Support for multiple programming languages, including Python, Java, and C#
# 	+ Customizable framework based on user preferences
# * **Database Management System**
# 	+ Integration with cloud-based databases (e.g., AWS, Google Cloud)
# 	+ Ability to scale up or down based on user demand
# * **Server Infrastructure**
# 	+ Customizable server infrastructure based on user needs
# 	+ Option for users to host their own servers
#
# IX. Non-Functional Requirements
#
# * **Usability and Accessibility**
# 	+ Integration with accessibility features, such as screen readers and high contrast mode
# 	+ Ability to adapt to different screen sizes and devices
# * **User Experience (UX) and User Interface (UI)**
# 	+ Customizable UI based on user preferences
# 	+ Integration with popular UX design tools (e.g., Sketch, Figma)
#
# **
# --------------------------------------------------
#
# 📜 GENERATED RESPONSE:
# --------------------------------------------------
# Here is a summary of the expanded functional requirements:
#
# **I. User Interaction Requirements**
#
# * Additional security measures for registration and authentication
# * Customizable account creation process
# * Character limit of 1000 characters for input validation
# * Integration with voice-to-text functionality for users with disabilities
#
# **II. Real-Time Study Support Requirements**
#
# * Additional question types, such as image or audio-based questions
# * Integration with popular study aids, like fla...
# --------------------------------------------------
#
# 🔍 CRITIQUE:
# --------------------------------------------------
# Clarity: 8/10
# The response is well-structured, with clear headings and concise descriptions of each requirement category. However, some sections feel a bit lengthy and could be broken up into smaller, more manageable chunks to improve overall readability.
#
# Completeness: 9/10
# The expanded functional requirements document covers most aspects of the system's functionality, security, performance, technical requirements, and non-functional requirements. However, there is a slight lack of detail in some areas, such as specific implementation details for certain features or technical requirements.
#
# Technical Accuracy: 8.5/10
# Most statements are factually correct and aligned with software engineering best practices. However, some minor inaccuracies or outdated information (e.g., regarding cloud-based database integration) can be improved to ensure the highest level of accuracy.
#
# Specificity: 7.5/10
# While the document provides a good overview of the system's capabilities, it sometimes lacks concrete, actionable details. For example, specific character limits for input validation or customizable study session lengths could be elaborated upon to provide more clarity.
#
# Feasibility: 8/10
# Most requirements seem realistic and implementable, but some might require additional resources or development time to fully realize. For instance, integrating with popular testing software or wearable devices may require significant effort and investment.
#
# Overall: 8.3/10
#
# Explanation:
# The expanded functional requirements document provides a solid foundation for the AI-powered Study Companion Discord Bot's development. While it excels in covering most aspects of functionality and security, there is room for improvement in terms of specificity, completeness, and technical accuracy. To enhance clarity, consider breaking up lengthy sections into smaller, more digestible chunks. Additionally, providing more concrete details and actionable steps can help ensure the highest level of feasibility and implementation success.
#
# Recommendations:
#
# 1.  Conduct thorough research to verify accuracy and update outdated information.
# 2.  Elaborate on specific requirements to provide concrete, actionable details.
# 3.  Consider adding more detailed implementation guides or technical notes for certain features.
# 4.  Review and refine the document's structure and organization to improve overall clarity and readability.
#
# By addressing these areas, you can further enhance the quality and effectiveness of the expanded functional requirements document, ensuring a successful development process for the AI-powered Study Companion Discord Bot.
# ==================================================
