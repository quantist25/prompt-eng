# %%
import json
import re
import time
import statistics
from _pipeline import create_payload, model_req

# Load previous best prompts with improved error handling
def load_prompt_history():
    try:
        with open("best_prompts.json", "r") as file:
            return json.load(file)
    except (FileNotFoundError, json.JSONDecodeError):
        print("Creating new prompt history database")
        return {}

# Enhanced domain-specific terminology with importance weights
important_terms = {
    "functional requirements": 15,
    "non-functional requirements": 15,
    "real-time study support": 10,
    "personalized tutoring": 10,
    "exam preparation": 10,
    "user experience": 12,
    "response time": 8,
    "scalability": 8,
    "security": 12,
    "integration": 10,
    "data privacy": 12,
    "accessibility": 10
}

def enhanced_score_response(response, metrics_only=False):
    """
    Enhanced scoring function with multiple evaluation dimensions
    Returns tuple: (final_score, detailed_metrics, critique)
    """
    # Initialize metrics dictionary
    metrics = {
        "word_count": len(response.split()),
        "keyword_matches": 0,
        "keyword_score": 0,
        "ai_critique_score": 0,
        "readability_score": 0
    }
    
    # Calculate keyword presence and weighted score
    for term, weight in important_terms.items():
        if term.lower() in response.lower():
            metrics["keyword_matches"] += 1
            metrics["keyword_score"] += weight
    
    # Simple readability metric (avg sentence length - prefer 15-20 words)
    sentences = [s.strip() for s in re.split(r'[.!?]', response) if s.strip()]
    if sentences:
        avg_sentence_length = statistics.mean([len(s.split()) for s in sentences])
        # Penalize sentences that are too short or too long
        if avg_sentence_length < 8:
            metrics["readability_score"] = 5
        elif avg_sentence_length > 30:
            metrics["readability_score"] = 6
        else:
            metrics["readability_score"] = 10
    
    # If only want metrics without AI critique (for faster iterations)
    if metrics_only:
        metrics["final_score"] = (
            metrics["word_count"] * 0.2 +
            metrics["keyword_score"] * 2 +
            metrics["readability_score"] * 5
        )
        return metrics["final_score"], metrics, "No critique requested"
        
    # AI-based multidimensional critique
    critic_prompt = f"""
    Perform a detailed evaluation of the following requirement analysis response for an AI-powered Study Companion Discord Bot.
    
    Evaluate based on these specific criteria:
    1. Clarity (1-10): Is the response well-structured, organized logically, and easy to understand?
    2. Completeness (1-10): Does it thoroughly cover both functional and non-functional requirements?
    3. Technical Accuracy (1-10): Are the statements factually correct and aligned with software engineering best practices?
    4. Specificity (1-10): Does it provide concrete, actionable details rather than vague statements?
    5. Feasibility (1-10): Are the requirements realistic and implementable?
    
    Response to evaluate:
    {response}
    
    Format your response exactly as follows:
    Clarity: [score]/10
    Completeness: [score]/10
    Technical Accuracy: [score]/10
    Specificity: [score]/10
    Feasibility: [score]/10
    Overall: [average score]/10
    
    Explanation: [brief justification for scores and specific improvement suggestions]
    """

    # Call the AI model to critique the response
    payload_critic = create_payload(
        target="ollama",
        model="llama3.2:latest",
        prompt=critic_prompt,
        temperature=0.4  # Lower temperature for more consistent evaluation
    )
    
    _, critic_feedback = model_req(payload_critic)
    
    # Extract all scores using regex
    scores = {}
    for criterion in ["Clarity", "Completeness", "Technical Accuracy", "Specificity", "Feasibility", "Overall"]:
        match = re.search(rf"{criterion}:\s*(\d+(?:\.\d+)?)/10", critic_feedback)
        if match:
            scores[criterion.lower()] = float(match.group(1))
    
    # Calculate average score if "Overall" wasn't extracted
    if "overall" not in scores and len(scores) > 0:
        scores["overall"] = sum(scores.values()) / len(scores)
    
    # Use overall score or default to 5
    critic_score = scores.get("overall", 5)
    metrics["ai_critique_score"] = critic_score * 10  # Scale to 0-100
    
    # Calculate final weighted score
    metrics["final_score"] = (
        metrics["word_count"] * 0.2 +           # 20% weight for length
        metrics["keyword_score"] * 2 +          # 40% weight for keywords
        metrics["ai_critique_score"] * 3 +      # 30% weight for AI critique
        metrics["readability_score"] * 5        # 10% weight for readability
    )
    
    return metrics["final_score"], metrics, critic_feedback

def generate_prompt_variations(base_prompt, n=3):
    """Generate multiple variations of a prompt to test effectiveness"""
    variation_prompt = f"""
    Create {n} variations of the following prompt. Each variation should maintain the same goal
    but experiment with different structures, emphasis, or approaches to potentially improve results.
    Make each variation distinctly different in structure or strategy.
    
    Original prompt:
    {base_prompt}
    
    Format your response as:
    VARIATION 1:
    [First complete prompt variation]
    
    VARIATION 2:
    [Second complete prompt variation]
    
    VARIATION 3:
    [Third complete prompt variation]
    """
    
    payload = create_payload(
        target="ollama",
        model="llama3.2:latest",
        prompt=variation_prompt,
        temperature=0.8,  # Higher temperature for more creative variations
        num_predict=2048
    )
    
    _, variations_text = model_req(payload)
    
    # Extract variations using regex
    variations = []
    for i in range(1, n+1):
        pattern = rf"VARIATION {i}:(.*?)(?:VARIATION {i+1}:|$)"
        match = re.search(pattern, variations_text, re.DOTALL)
        if match:
            variations.append(match.group(1).strip())
    
    # If extraction failed, fall back to simpler method
    if not variations:
        variations = [base_prompt]
        print("Failed to generate distinct variations")
    
    return variations

# Main optimization process
def optimize_prompt_pipeline():
    # Load prompt history at the beginning of the function
    prompt_history = load_prompt_history()
    
    # Step 1: Generate initial meta-prompt
    meta_prompt = (
        "Create a highly structured prompt that extracts detailed functional and non-functional "
        "requirements for an AI-powered Study Companion Discord Bot. The structured prompt should "
        "elicit comprehensive, technically precise, and actionable requirements spanning user "
        "interaction, performance criteria, security measures, and integration capabilities. "
        "Include specific sections for real-time study support, personalized tutoring, and exam preparation. "
        "The prompt should guide the response to be well-organized with clear categorization."
    )
    
    payload_meta = create_payload(
        target="ollama",
        model="llama3.2:latest",
        prompt=meta_prompt,
        temperature=0.7
    )
    _, base_prompt = model_req(payload_meta)
    print("✓ Generated base prompt")
    
    # Step 2: Generate multiple prompt variations
    prompt_variations = generate_prompt_variations(base_prompt, n=3)
    print(f"✓ Created {len(prompt_variations)} prompt variations")
    
    # Step 3: Test all variations
    results = []
    
    for i, prompt in enumerate(prompt_variations):
        print(f"Testing variation {i+1}...")
        
        # Execute prompt
        payload_exec = create_payload(
            target="ollama",
            model="llama3.2:latest",
            prompt=prompt,
            temperature=0.9,  # Slightly higher for creative requirements
            num_ctx=4096,
            num_predict=2048
        )
        _, response = model_req(payload_exec)
        
        # Score the response
        score, metrics, critique = enhanced_score_response(response)
        
        results.append({
            "prompt": prompt,
            "response": response,
            "score": score,
            "metrics": metrics,
            "critique": critique
        })
        
        print(f"  Score: {score:.2f}")
    
    # Sort by score (descending)
    results.sort(key=lambda x: x["score"], reverse=True)
    best_result = results[0]
    
    # Step 4: Refine the best prompt based on critique
    refinement_prompt = f"""
    Refine this prompt based on the following critique of the response it generated.
    
    Original prompt:
    {best_result["prompt"]}
    
    Response critique:
    {best_result["critique"]}
    
    Create an improved version of the prompt that addresses the weaknesses identified in the critique
    while maintaining its strengths. Focus especially on eliciting more specific, actionable, and
    comprehensive requirements.
    """
    
    payload_refine = create_payload(
        target="ollama",
        model="llama3.2:latest",
        prompt=refinement_prompt,
        temperature=0.6
    )
    _, refined_prompt = model_req(payload_refine)
    print("✓ Generated refined prompt")
    
    # Step 5: Test the refined prompt
    payload_refined_exec = create_payload(
        target="ollama",
        model="llama3.2:latest",
        prompt=refined_prompt,
        temperature=0.9,
        num_ctx=4096,
        num_predict=2048
    )
    _, refined_response = model_req(payload_refined_exec)
    
    refined_score, refined_metrics, refined_critique = enhanced_score_response(refined_response)
    print(f"✓ Refined prompt score: {refined_score:.2f}")
    
    # Step 6: Compare and select the best overall
    all_results = results + [{
        "prompt": refined_prompt,
        "response": refined_response,
        "score": refined_score,
        "metrics": refined_metrics,
        "critique": refined_critique
    }]
    
    all_results.sort(key=lambda x: x["score"], reverse=True)
    champion = all_results[0]
    
    # Save to history
    timestamp = time.strftime("%Y%m%d_%H%M%S")
    prompt_history[timestamp] = {
        "prompt": champion["prompt"],
        "score": champion["score"],
        "metrics": champion["metrics"]
    }
    
    # Save top 3 prompts to file
    with open("best_prompts.json", "w") as file:
        # Only store recent and high-scoring prompts (up to 20)
        if len(prompt_history) > 20:
            sorted_history = sorted(
                prompt_history.items(),
                key=lambda x: x[1].get("score", 0),
                reverse=True
            )
            prompt_history = dict(sorted_history[:20])
        
        json.dump(prompt_history, file, indent=4)
    
    # Output Results
    print("\n" + "="*50)
    print("OPTIMIZATION RESULTS")
    print("="*50)
    print(f"🏆 Best Score: {champion['score']:.2f}")
    print(f"📊 Metrics: {champion['metrics']}")
    print("\n✅ BEST OPTIMIZED PROMPT:")
    print("-"*50)
    print(champion["prompt"])
    print("-"*50)
    print("\n📜 GENERATED RESPONSE:")
    print("-"*50)
    print(champion["response"][:500] + "..." if len(champion["response"]) > 500 else champion["response"])
    print("-"*50)
    print("\n🔍 CRITIQUE:")
    print("-"*50)
    print(champion["critique"])
    print("="*50)
    
    return champion

# Run the optimization pipeline
if __name__ == "__main__":
    optimize_prompt_pipeline()
# Out:
# {'model': 'llama3.2:latest', 'prompt': 'Create a highly structured prompt that extracts detailed functional and non-functional requirements for an AI-powered Study Companion Discord Bot. The structured prompt should elicit comprehensive, technically precise, and actionable requirements spanning user interaction, performance criteria, security measures, and integration capabilities. Include specific sections for real-time study support, personalized tutoring, and exam preparation. The prompt should guide the response to be well-organized with clear categorization.', 'stream': False, 'options': {'temperature': 0.7}}
# ✓ Generated base prompt
# {'model': 'llama3.2:latest', 'prompt': "\n    Create 3 variations of the following prompt. Each variation should maintain the same goal\n    but experiment with different structures, emphasis, or approaches to potentially improve results.\n    Make each variation distinctly different in structure or strategy.\n    \n    Original prompt:\n    **Discord Bot Requirements: AI-Powered Study Companion**\n\n**Section 1: User Interaction Requirements**\n\n1. **User Profile Management**\n\t* Create a user profile system that allows users to:\n\t\t+ Register and login\n\t\t+ Set up their study goals, interests, and preferred learning style\n\t\t+ Update their profile information (name, email, etc.)\n2. **Chat Interface**\n\t* Design an intuitive chat interface for users to interact with the bot\n\t* Include features such as:\n\t\t+ Text input for sending messages or asking questions\n\t\t+ Rich media support for images, videos, and files\n\t\t+ Emojis and reactions for enhanced user experience\n3. **Command Syntax**\n\t* Develop a clear command syntax that users can follow to interact with the bot\n\t* Include basic commands such as:\n\t\t+ `!help` - display available commands and features\n\t\t+ `!study` - set study goals or schedule\n\t\t+ `!tutor` - request personalized tutoring\n\n**Section 2: Functional Requirements**\n\n1. **Real-Time Study Support**\n\t* Develop a system that provides real-time study support, including:\n\t\t+ Instant messaging with the bot for questions and clarification\n\t\t+ Personalized recommendations for relevant resources (e.g., textbooks, articles)\n\t\t+ Integration with calendar apps to schedule study sessions\n2. **Personalized Tutoring**\n\t* Implement personalized tutoring capabilities that take into account user learning style and goals\n\t* Include features such as:\n\t\t+ Adaptive difficulty adjustment based on user performance\n\t\t+ Customizable lesson plans tailored to individual needs\n3. **Exam Preparation**\n\t* Develop a system that helps users prepare for exams, including:\n\t\t+ Practice quizzes with adaptive difficulty adjustment\n\t\t+ Flashcards with spaced repetition for memorization\n\t\t+ Review schedules and reminders for upcoming exams\n\n**Section 3: Performance Criteria**\n\n1. **Response Time**\n\t* Ensure the bot responds within a reasonable time frame (e.g., < 10 seconds) to user queries\n2. **Accuracy**\n\t* Develop an accuracy metric that measures the bot's performance in providing relevant information and correct answers\n3. **Scalability**\n\t* Design the system to scale with increasing user traffic, ensuring minimal impact on performance\n\n**Section 4: Security Measures**\n\n1. **Data Encryption**\n\t* Encrypt all user data (e.g., profile information, study goals) using a secure protocol (e.g., SSL/TLS)\n2. **Access Control**\n\t* Implement access controls to restrict user access to sensitive features (e.g., personalized tutoring) based on their permissions\n3. **Bot Behavior Monitoring**\n\t* Regularly monitor the bot's behavior for potential security vulnerabilities or suspicious activity\n\n**Section 5: Integration Capabilities**\n\n1. **Calendar Integration**\n\t* Integrate with popular calendar apps (e.g., Google Calendar, Apple Calendar) to schedule study sessions and reminders\n2. **Resource Integration**\n\t* Integrate with relevant resources (e.g., textbook publishers, educational websites) to provide users with personalized recommendations\n3. **Third-Party App Integration**\n\t* Explore integration opportunities with popular third-party apps (e.g., productivity tools, browser extensions)\n\n**Section 6: Additional Requirements**\n\n1. **User Feedback Mechanism**\n\t* Develop a system for users to provide feedback and suggestions on the bot's performance and features\n2. **Bug Reporting System**\n\t* Implement a bug reporting system that allows users to report issues or errors with the bot\n3. **Bot Maintenance Schedule**\n\t* Establish a regular maintenance  ...
# ✓ Created 3 prompt variations
# Testing variation 1...
# {'model': 'llama3.2:latest', 'prompt': "FOCUS ON USER EXPERIENCE**\n\nDiscord Bot Requirements: AI-Powered Study Companion\n\n**Core Principles**\n\n* User-centric design prioritizing ease of use, accessibility, and engagement\n* Personalized experience through adaptive learning style and goal-based support\n* Intuitive chat interface with rich media support and emojis for a delightful user experience\n\n**Section 1: User Interaction and Profile Management**\n\n1. **User Onboarding**\n\t* Guide users through a streamlined registration and setup process\n\t* Introduce features and functionalities to help users get started quickly\n2. **Chat Interface Customization**\n\t* Offer customization options for the chat interface, including font sizes, colors, and emojis\n\t* Provide a clear and concise feedback mechanism for users to report issues or suggestions\n3. **Profile Management and Data Security**\n\t* Implement robust data encryption protocols to safeguard user data\n\t* Ensure secure access controls and authentication mechanisms to protect sensitive information\n\n**Section 2: Real-Time Study Support and Personalized Tutoring**\n\n1. **Real-Time Messaging**\n\t* Develop a fast and reliable messaging system for instant support and clarification\n\t* Integrate with popular calendar apps for scheduling study sessions and reminders\n2. **Adaptive Learning Pathways**\n\t* Implement adaptive learning pathways that adjust to individual learning styles and goals\n\t* Incorporate personalized tutoring capabilities with AI-driven assessment and feedback\n\n**Section 3: Performance and Scalability**\n\n1. **Response Time and Latency**\n\t* Optimize the bot's response time and latency for seamless user experience\n\t* Monitor performance metrics to ensure minimal impact on scalability\n2. **Scalability and Load Management**\n\t* Design the system to scale with increasing user traffic, ensuring minimal downtime or performance degradation\n\t* Implement load management strategies to prevent server overload and maintain responsiveness\n\n**Section 4: Security Measures**\n\n1. **Data Encryption and Access Control**\n\t* Ensure robust data encryption protocols for all user data\n\t* Implement strict access controls and authentication mechanisms to protect sensitive information\n2. **Regular Security Audits and Updates**\n\t* Conduct regular security audits to identify vulnerabilities and address potential issues\n\t* Maintain up-to-date software and security patches to prevent exploitation\n\n**Section 5: Integration Capabilities**\n\n1. **Calendar Integration and Resource Recommendations**\n\t* Integrate with popular calendar apps for scheduling study sessions and reminders\n\t* Provide users with personalized resource recommendations based on their learning style and goals\n2. **Third-Party App Integration and Collaboration**\n\t* Explore integration opportunities with popular third-party apps to enhance user experience\n\t* Implement collaboration tools for seamless sharing of resources, notes, and progress\n\n**Section 6: Additional Requirements**\n\n1. **User Feedback Mechanism and Bug Reporting System**\n\t* Develop a comprehensive feedback mechanism for users to report issues or suggestions\n\t* Implement a robust bug reporting system with clear instructions and easy submission process\n2. **Bot Maintenance Schedule and Regular Updates**\n\t* Establish a regular maintenance schedule for the bot, including updates, patches, and security audits\n\t* Communicate changes and updates clearly to maintain transparency and trust\n\n**", 'stream': False, 'options': {'temperature': 0.9, 'num_ctx': 4096, 'num_predict': 2048}}
# {'model': 'llama3.2:latest', 'prompt': "\n    Perform a detailed evaluation of the following requirement analysis response for an AI-powered Study Companion Discord Bot.\n    \n    Evaluate based on these specific criteria:\n    1. Clarity (1-10): Is the response well-structured, organized logically, and easy to understand?\n    2. Completeness (1-10): Does it thoroughly cover both functional and non-functional requirements?\n    3. Technical Accuracy (1-10): Are the statements factually correct and aligned with software engineering best practices?\n    4. Specificity (1-10): Does it provide concrete, actionable details rather than vague statements?\n    5. Feasibility (1-10): Are the requirements realistic and implementable?\n    \n    Response to evaluate:\n    Based on the provided Discord Bot Requirements: AI-Powered Study Companion, I'll outline a comprehensive plan for developing a user-centric study companion with adaptive learning style, goal-based support, and an intuitive chat interface.\n\n**User Experience (UX) Principles**\n\n1. **Simple Onboarding Process**: Create a guided registration process that introduces users to the bot's features and functionalities.\n2. **Customizable Chat Interface**: Offer font size, color, and emoji customization options to cater to individual preferences.\n3. **Clear Feedback Mechanism**: Implement a user-friendly feedback system for reporting issues or suggestions.\n\n**Core Features**\n\n1. **Real-Time Messaging**: Develop a fast and reliable messaging system with instant support and clarification capabilities.\n2. **Adaptive Learning Pathways**: Implement adaptive learning pathways that adjust to individual learning styles and goals, incorporating AI-driven assessment and feedback.\n3. **Personalized Tutoring**: Offer personalized tutoring capabilities with real-time guidance and support.\n\n**Technical Requirements**\n\n1. **Data Encryption and Access Control**: Ensure robust data encryption protocols (e.g., SSL/TLS) for user data protection.\n2. **Scalability and Load Management**: Design the system to scale with increasing user traffic, using load management strategies to prevent server overload.\n3. **Regular Security Audits and Updates**: Conduct regular security audits and maintain up-to-date software and security patches.\n\n**Development Roadmap**\n\nPhase 1: Core Features Development (Weeks 1-8)\n\n* Develop real-time messaging system\n* Implement adaptive learning pathways with AI-driven assessment and feedback\n* Create personalized tutoring capabilities\n\nPhase 2: UI/UX Refining and Testing (Weeks 9-16)\n\n* Conduct usability testing and refine the chat interface\n* Gather user feedback and iterate on the design\n* Ensure data encryption and access control protocols are in place\n\nPhase 3: Security Measures and Deployment (Weeks 17-24)\n\n* Implement regular security audits and updates\n* Deploy the bot with scalability and load management strategies\n\n**Key Performance Indicators (KPIs)**\n\n1. **User Adoption Rate**: Monitor the number of users who complete the onboarding process.\n2. **Engagement Metrics**: Track user engagement through messaging system usage, feedback, and tutorial completion rates.\n3. **Learning Outcomes**: Measure the effectiveness of adaptive learning pathways in improving learning outcomes.\n\n**Post-Launch Evaluation**\n\n1. **User Feedback Mechanism**: Gather feedback from users to identify areas for improvement.\n2. **Security Audits**: Conduct regular security audits to ensure the bot remains secure and up-to-date.\n3. **Continuous Testing and Refining**: Continuously test and refine the chat interface, features, and performance.\n\nBy following this plan, you'll create an AI-powered study companion that provides a user-centric experience with adaptive learning style, goal-based support, and an intuitive chat interface.\n    \n    Format your response exactly as follows:\n    Clarity: [score]/10\n    Completeness: [score]/10\n    Techni ...
#   Score: 454.60
# Testing variation 2...
# {'model': 'llama3.2:latest', 'prompt': 'EMPHASIZING FUNCTIONALITY AND FEATURES**\n\nDiscord Bot Requirements: AI-Powered Study Companion\n\n**Core Principles**\n\n* Focus on delivering robust features and functionalities that support effective learning and study habits\n* Prioritize accuracy, reliability, and consistency in performance and response time\n* Integrate with popular tools and platforms to enhance user experience and productivity\n\n**Section 1: User Interaction and Profile Management**\n\n1. **Advanced Chat Interface Features**\n\t* Implement rich media support for images, videos, and files\n\t* Offer advanced formatting options for text input, including tables, quotes, and emojis\n2. **Customizable Learning Plans**\n\t* Provide users with the ability to create custom learning plans tailored to their needs and goals\n\t* Incorporate AI-driven recommendations for relevant resources, textbooks, and articles\n\n**Section 2: Real-Time Study Support and Personalized Tutoring**\n\n1. **Practice Quizzes and Adaptive Difficulty Adjustment**\n\t* Develop practice quizzes that adjust to individual performance levels and provide personalized feedback\n\t* Implement adaptive difficulty adjustment based on user progress and performance metrics\n2. **Flashcards with Spaced Repetition**\n\t* Create flashcards with spaced repetition for efficient memorization and recall\n\t* Incorporate AI-driven algorithms to optimize flashcard creation, retrieval, and review\n\n**Section 3: Performance and Scalability**\n\n1. **High-Performance Server Architecture**\n\t* Design a high-performance server architecture with load management strategies to prevent server overload\n\t* Optimize database queries for fast data retrieval and processing\n2. **Data Analytics and Insights**\n\t* Develop a robust data analytics system to track user performance, progress, and engagement metrics\n\t* Provide actionable insights and recommendations for users to optimize their learning habits\n\n**Section 4: Security Measures**\n\n1. **Advanced Data Encryption Protocols**\n\t* Implement advanced encryption protocols, including end-to-end encryption and secure key exchange\n\t* Ensure secure data storage and transmission using secure sockets layer (SSL) or transport layer security (TLS)\n2. **Regular Security Audits and Penetration Testing**\n\t* Conduct regular security audits to identify vulnerabilities and address potential issues\n\t* Perform penetration testing to simulate real-world attacks and improve overall security posture\n\n**Section 5: Integration Capabilities**\n\n1. **Calendar Integration with Scheduling and Reminders**\n\t* Integrate calendar apps for scheduling study sessions, reminders, and notifications\n\t* Offer customizable notification preferences and alerts for important events and deadlines\n2. **Third-Party App Integration for Collaboration and Sharing**\n\t* Explore integration opportunities with popular third-party apps for collaboration, sharing, and resource exchange\n\t* Implement features for seamless sharing of notes, progress, and feedback\n\n**Section 6: Additional Requirements**\n\n1. **User Feedback Mechanism with AI-Driven Insights**\n\t* Develop a comprehensive feedback mechanism that incorporates AI-driven insights and recommendations\n\t* Use machine learning algorithms to analyze user feedback and improve the overall experience\n2. **Bot Maintenance Schedule with Clear Communication**\n\t* Establish a regular maintenance schedule for the bot, including updates, patches, and security audits\n\t* Communicate changes and updates clearly to maintain transparency and trust with users\n\n**', 'stream': False, 'options': {'temperature': 0.9, 'num_ctx': 4096, 'num_predict': 2048}}
# {'model': 'llama3.2:latest', 'prompt': "\n    Perform a detailed evaluation of the following requirement analysis response for an AI-powered Study Companion Discord Bot.\n    \n    Evaluate based on these specific criteria:\n    1. Clarity (1-10): Is the response well-structured, organized logically, and easy to understand?\n    2. Completeness (1-10): Does it thoroughly cover both functional and non-functional requirements?\n    3. Technical Accuracy (1-10): Are the statements factually correct and aligned with software engineering best practices?\n    4. Specificity (1-10): Does it provide concrete, actionable details rather than vague statements?\n    5. Feasibility (1-10): Are the requirements realistic and implementable?\n    \n    Response to evaluate:\n    Based on the provided requirements, I'll outline a plan for developing an AI-powered study companion Discord bot. Here's a high-level overview of the development process:\n\n**Phase 1: Planning and Research (Weeks 1-4)**\n\n1. Conduct market research to identify competitors and gaps in the market.\n2. Define the target audience and their learning needs.\n3. Determine the scope and features for the first release.\n4. Create a detailed project plan, timeline, and resource allocation.\n\n**Phase 2: Development (Weeks 5-20)**\n\n1. **Frontend Development**\n\t* Design and implement the chat interface with rich media support, formatting options, and advanced formatting capabilities.\n\t* Integrate calendar apps for scheduling study sessions, reminders, and notifications.\n2. **Backend Development**\n\t* Develop the database schema to store user profiles, learning plans, practice quizzes, flashcards, and analytics data.\n\t* Implement AI-driven recommendations, adaptive difficulty adjustment, and spaced repetition algorithms.\n3. **AI-Driven Features**\n\t* Develop a natural language processing (NLP) module for understanding user intent and providing personalized feedback.\n\t* Integrate machine learning algorithms to analyze user feedback, identify areas of improvement, and make data-driven decisions.\n\n**Phase 3: Testing and Quality Assurance (Weeks 21-24)**\n\n1. Conduct unit testing, integration testing, and regression testing for each component.\n2. Perform UI/UX testing to ensure a smooth and intuitive experience.\n3. Test the bot's scalability, performance, and reliability under various loads.\n\n**Phase 4: Launch Preparation (Weeks 25-28)**\n\n1. Prepare the bot for launch by optimizing database queries, load management strategies, and security measures.\n2. Develop a comprehensive documentation set, including user guides, API references, and troubleshooting resources.\n3. Establish a support channel for users to report issues, provide feedback, and receive updates.\n\n**Phase 5: Launch and Maintenance (After Week 28)**\n\n1. Launch the bot and announce it to the community through social media, Discord channels, and partnerships.\n2. Monitor user feedback, analytics data, and performance metrics to identify areas of improvement.\n3. Conduct regular security audits, penetration testing, and updates to ensure the bot's reliability and performance.\n\n**Estimated Development Time:** 24 weeks (~6 months)\n\n**Team Size:**\n\n* 1 lead developer\n* 2 frontend developers\n* 2 backend developers\n* 1 AI/ML engineer\n* 1 QA engineer\n\n**Budget Allocation:**\n\n* Frontend development: 30%\n* Backend development: 40%\n* AI-driven features: 15%\n* Testing and quality assurance: 10%\n* Launch preparation and maintenance: 5%\n\nNote that this is a rough estimate, and the actual development time, team size, and budget allocation may vary depending on the specific requirements, technologies, and resources used.\n    \n    Format your response exactly as follows:\n    Clarity: [score]/10\n    Completeness: [score]/10\n    Technical Accuracy: [score]/10\n    Specificity: [score]/10\n    Feasibility: [score]/10\n    Overall: [average score]/10\n    \n    Explanation: [brief justific ...
#   Score: 416.40
# Testing variation 3...
# {'model': 'llama3.2:latest', 'prompt': "FOCUSING ON USER EXPERIENCE AND PERSONALIZATION**\n\nDiscord Bot Requirements: AI-Powered Study Companion\n\n**Core Principles**\n\n* Prioritize delivering a seamless and personalized user experience that supports effective learning and study habits\n* Emphasize the importance of empathy, understanding, and human interaction in the development process\n* Incorporate user-centered design principles and human-computer interaction techniques to enhance usability and accessibility\n\n**Section 1: User Interaction and Profile Management**\n\n1. **Intuitive Chat Interface Design**\n\t* Implement a clean, intuitive, and visually appealing chat interface that minimizes cognitive load\n\t* Offer clear and concise language for onboarding, support, and feedback mechanisms\n2. **Personalized Learning Profiles**\n\t* Develop personalized learning profiles that adapt to individual learning styles, goals, and preferences\n\t* Incorporate AI-driven recommendations for relevant resources, textbooks, and articles based on user profile data\n\n**Section 2: Real-Time Study Support and Personalized Tutoring**\n\n1. **Emotional Intelligence and Empathy in Chatbot Interactions**\n\t* Implement emotional intelligence and empathy mechanisms to understand and respond to users' emotions and needs\n\t* Use natural language processing (NLP) techniques to analyze user input and provide personalized feedback\n2. **Adaptive Learning Pathways with Gamification and Motivation**\n\t* Develop adaptive learning pathways that incorporate gamification elements, such as rewards, badges, and leaderboards\n\t* Use AI-driven algorithms to adjust difficulty levels, provide personalized feedback, and motivate users\n\n**Section 3: Performance and Scalability**\n\n1. **High-Performance Server Architecture with Load Management**\n\t* Design a high-performance server architecture with load management strategies to prevent server overload\n\t* Optimize database queries for fast data retrieval and processing\n2. **User Feedback Mechanism with Real-Time Insights**\n\t* Develop a comprehensive feedback mechanism that provides real-time insights into user performance, progress, and engagement metrics\n\t* Use machine learning algorithms to analyze user feedback and improve the overall experience\n\n**Section 4: Security Measures**\n\n1. **Advanced Data Encryption Protocols with End-to-End Encryption**\n\t* Implement advanced encryption protocols that ensure end-to-end encryption for all user data\n\t* Ensure secure data storage and transmission using secure sockets layer (SSL) or transport layer security (TLS)\n2. **Regular Security Audits with Human Oversight**\n\t* Conduct regular security audits to identify vulnerabilities and address potential issues\n\t* Use human oversight and review processes to ensure the accuracy and reliability of security assessments\n\n**Section 5: Integration Capabilities**\n\n1. **Calendar Integration with Scheduling, Reminders, and Notifications**\n\t* Integrate calendar apps for scheduling study sessions, reminders, and notifications\n\t* Offer customizable notification preferences and alerts for important events and deadlines\n2. **Third-Party App Integration with Collaboration and Sharing**\n\t* Explore integration opportunities with popular third-party apps for collaboration, sharing, and resource exchange\n\t* Implement features for seamless sharing of notes, progress, and feedback\n\n**Section 6: Additional Requirements**\n\n1. **User Feedback Mechanism with AI-Driven Insights and Recommendations**\n\t* Develop a comprehensive feedback mechanism that incorporates AI-driven insights and recommendations\n\t* Use machine learning algorithms to analyze user feedback and improve the overall experience\n2. **Bot Maintenance Schedule with Human Oversight and Communication**\n\t* Establish a regular maintenance schedule for the bot, including updates, patches, and security audits\n\t* Communicate changes and u ...
# {'model': 'llama3.2:latest', 'prompt': "\n    Perform a detailed evaluation of the following requirement analysis response for an AI-powered Study Companion Discord Bot.\n    \n    Evaluate based on these specific criteria:\n    1. Clarity (1-10): Is the response well-structured, organized logically, and easy to understand?\n    2. Completeness (1-10): Does it thoroughly cover both functional and non-functional requirements?\n    3. Technical Accuracy (1-10): Are the statements factually correct and aligned with software engineering best practices?\n    4. Specificity (1-10): Does it provide concrete, actionable details rather than vague statements?\n    5. Feasibility (1-10): Are the requirements realistic and implementable?\n    \n    Response to evaluate:\n    **Discord Bot Requirements: AI-Powered Study Companion**\n\nThe following is an expanded version of the original requirements, incorporating additional features and considerations:\n\n**Core Principles**\n\n1. **Emphasis on User Experience**: Prioritize delivering a seamless and personalized user experience that supports effective learning and study habits.\n2. **Human-Centered Design**: Incorporate user-centered design principles and human-computer interaction techniques to enhance usability and accessibility.\n3. **Empathy and Emotional Intelligence**: Emphasize the importance of empathy, understanding, and emotional intelligence in the development process.\n\n**Section 1: User Interaction and Profile Management**\n\n1. **Intuitive Chat Interface Design**\n\t* Implement a clean, intuitive, and visually appealing chat interface that minimizes cognitive load.\n\t* Offer clear and concise language for onboarding, support, and feedback mechanisms.\n2. **Personalized Learning Profiles**\n\t* Develop personalized learning profiles that adapt to individual learning styles, goals, and preferences.\n\t* Incorporate AI-driven recommendations for relevant resources, textbooks, and articles based on user profile data.\n3. **Biometric Authentication and Verification**\n\t* Implement biometric authentication (e.g., fingerprint or facial recognition) to ensure secure login and verification processes.\n\n**Section 2: Real-Time Study Support and Personalized Tutoring**\n\n1. **Emotional Intelligence and Empathy in Chatbot Interactions**\n\t* Implement emotional intelligence and empathy mechanisms to understand and respond to users' emotions and needs.\n\t* Use natural language processing (NLP) techniques to analyze user input and provide personalized feedback.\n2. **Adaptive Learning Pathways with Gamification and Motivation**\n\t* Develop adaptive learning pathways that incorporate gamification elements, such as rewards, badges, and leaderboards.\n\t* Use AI-driven algorithms to adjust difficulty levels, provide personalized feedback, and motivate users.\n3. **Virtual Mentorship and Peer Support**\n\t* Offer virtual mentorship opportunities for students, providing guidance and support from experienced peers or professionals.\n\t* Implement a peer support system that facilitates connections between users with similar interests and goals.\n\n**Section 3: Performance and Scalability**\n\n1. **High-Performance Server Architecture with Load Management**\n\t* Design a high-performance server architecture with load management strategies to prevent server overload.\n\t* Optimize database queries for fast data retrieval and processing.\n2. **User Feedback Mechanism with Real-Time Insights**\n\t* Develop a comprehensive feedback mechanism that provides real-time insights into user performance, progress, and engagement metrics.\n\t* Use machine learning algorithms to analyze user feedback and improve the overall experience.\n3. **Content Delivery Network (CDN) Integration**\n\t* Integrate a content delivery network (CDN) for efficient and secure content delivery.\n\n**Section 4: Security Measures**\n\n1. **Advanced Data Encryption Protocols with End-to-End Encryption**\n\t* Implement advanced ...
#   Score: 614.00
# {'model': 'llama3.2:latest', 'prompt': '\n    Refine this prompt based on the following critique of the response it generated.\n    \n    Original prompt:\n    FOCUSING ON USER EXPERIENCE AND PERSONALIZATION**\n\nDiscord Bot Requirements: AI-Powered Study Companion\n\n**Core Principles**\n\n* Prioritize delivering a seamless and personalized user experience that supports effective learning and study habits\n* Emphasize the importance of empathy, understanding, and human interaction in the development process\n* Incorporate user-centered design principles and human-computer interaction techniques to enhance usability and accessibility\n\n**Section 1: User Interaction and Profile Management**\n\n1. **Intuitive Chat Interface Design**\n\t* Implement a clean, intuitive, and visually appealing chat interface that minimizes cognitive load\n\t* Offer clear and concise language for onboarding, support, and feedback mechanisms\n2. **Personalized Learning Profiles**\n\t* Develop personalized learning profiles that adapt to individual learning styles, goals, and preferences\n\t* Incorporate AI-driven recommendations for relevant resources, textbooks, and articles based on user profile data\n\n**Section 2: Real-Time Study Support and Personalized Tutoring**\n\n1. **Emotional Intelligence and Empathy in Chatbot Interactions**\n\t* Implement emotional intelligence and empathy mechanisms to understand and respond to users\' emotions and needs\n\t* Use natural language processing (NLP) techniques to analyze user input and provide personalized feedback\n2. **Adaptive Learning Pathways with Gamification and Motivation**\n\t* Develop adaptive learning pathways that incorporate gamification elements, such as rewards, badges, and leaderboards\n\t* Use AI-driven algorithms to adjust difficulty levels, provide personalized feedback, and motivate users\n\n**Section 3: Performance and Scalability**\n\n1. **High-Performance Server Architecture with Load Management**\n\t* Design a high-performance server architecture with load management strategies to prevent server overload\n\t* Optimize database queries for fast data retrieval and processing\n2. **User Feedback Mechanism with Real-Time Insights**\n\t* Develop a comprehensive feedback mechanism that provides real-time insights into user performance, progress, and engagement metrics\n\t* Use machine learning algorithms to analyze user feedback and improve the overall experience\n\n**Section 4: Security Measures**\n\n1. **Advanced Data Encryption Protocols with End-to-End Encryption**\n\t* Implement advanced encryption protocols that ensure end-to-end encryption for all user data\n\t* Ensure secure data storage and transmission using secure sockets layer (SSL) or transport layer security (TLS)\n2. **Regular Security Audits with Human Oversight**\n\t* Conduct regular security audits to identify vulnerabilities and address potential issues\n\t* Use human oversight and review processes to ensure the accuracy and reliability of security assessments\n\n**Section 5: Integration Capabilities**\n\n1. **Calendar Integration with Scheduling, Reminders, and Notifications**\n\t* Integrate calendar apps for scheduling study sessions, reminders, and notifications\n\t* Offer customizable notification preferences and alerts for important events and deadlines\n2. **Third-Party App Integration with Collaboration and Sharing**\n\t* Explore integration opportunities with popular third-party apps for collaboration, sharing, and resource exchange\n\t* Implement features for seamless sharing of notes, progress, and feedback\n\n**Section 6: Additional Requirements**\n\n1. **User Feedback Mechanism with AI-Driven Insights and Recommendations**\n\t* Develop a comprehensive feedback mechanism that incorporates AI-driven insights and recommendations\n\t* Use machine learning algorithms to analyze user feedback and improve the overall experience\n2. **Bot Maintenance Schedule with Human Oversight and Communication**\n\t* Establish a ...
# ✓ Generated refined prompt
# {'model': 'llama3.2:latest', 'prompt': "Here's a refined version of the original prompt:\n\n**Discord Bot Requirements: AI-Powered Study Companion**\n\n**Core Principles**\n\n* Deliver a seamless and personalized user experience that supports effective learning and study habits\n* Emphasize empathy, understanding, and human interaction in the development process\n* Incorporate user-centered design principles and human-computer interaction techniques to enhance usability and accessibility\n\n**Section 1: User Interaction and Profile Management**\n\n1. **Intuitive Chat Interface Design**\n\t* Implement a clean, intuitive, and visually appealing chat interface with:\n\t\t+ Clear onboarding and support mechanisms (e.g., FAQs, in-app help)\n\t\t+ Customizable notification settings for study reminders and updates\n\t\t+ Emojis and emoticons to enhance user engagement\n2. **Personalized Learning Profiles**\n\t* Develop AI-driven learning profiles that adapt to individual:\n\t\t+ Learning styles (e.g., visual, auditory, kinesthetic)\n\t\t+ Goals and objectives (e.g., academic, professional, personal)\n\t\t+ Preferences for resource types (e.g., textbooks, articles, videos)\n\t* Incorporate natural language processing (NLP) techniques to analyze user input and provide personalized feedback\n\n**Section 2: Real-Time Study Support and Personalized Tutoring**\n\n1. **Emotional Intelligence and Empathy in Chatbot Interactions**\n\t* Implement emotional intelligence and empathy mechanisms using:\n\t\t+ Text-based sentiment analysis\n\t\t+ Emotional state detection (e.g., stress, anxiety, excitement)\n\t\t+ Predefined response templates for common user emotions\n2. **Adaptive Learning Pathways with Gamification and Motivation**\n\t* Develop adaptive learning pathways that incorporate gamification elements, such as:\n\t\t+ Points system for completing study sessions and achieving milestones\n\t\t+ Badges and leaderboards for tracking progress and competition\n\t\t+ Personalized motivational messages and encouragement\n\n**Section 3: Performance and Scalability**\n\n1. **High-Performance Server Architecture with Load Management**\n\t* Design a high-performance server architecture with load management strategies, including:\n\t\t+ Cloud-based infrastructure (e.g., AWS, Google Cloud)\n\t\t+ Caching mechanisms for improving response times\n\t\t+ Automated scaling to handle increased traffic and user demand\n2. **User Feedback Mechanism with Real-Time Insights**\n\t* Develop a comprehensive feedback mechanism that provides real-time insights into:\n\t\t+ User performance and progress metrics (e.g., accuracy, completion rate)\n\t\t+ Study session duration and engagement metrics (e.g., time spent on task, number of questions attempted)\n\n**Section 4: Security Measures**\n\n1. **Advanced Data Encryption Protocols with End-to-End Encryption**\n\t* Implement advanced encryption protocols that ensure end-to-end encryption for all user data, including:\n\t\t+ SSL/TLS certificates\n\t\t+ AES-256 bit encryption\n\t\t+ Secure key management and storage\n\n**Section 5: Integration Capabilities**\n\n1. **Calendar Integration with Scheduling, Reminders, and Notifications**\n\t* Integrate calendar apps (e.g., Google Calendar, Microsoft Exchange) for:\n\t\t+ Scheduling study sessions and reminders\n\t\t+ Customizable notification preferences and alerts\n2. **Third-Party App Integration with Collaboration and Sharing**\n\t* Explore integration opportunities with popular third-party apps for collaboration, sharing, and resource exchange, including:\n\t\t+ Educational platforms (e.g., Coursera, edX)\n\t\t+ Productivity tools (e.g., Evernote, Trello)\n\n**Section 6: Additional Requirements**\n\n1. **Bot Maintenance Schedule with Human Oversight and Communication**\n\t* Establish a regular maintenance schedule for the bot, including:\n\t\t+ Bi-weekly updates and patches\n\t\t+ Quarterly security audits and vulnerability assessments\n\t\t+ Monthly user feedback sessi ...
# {'model': 'llama3.2:latest', 'prompt': "\n    Perform a detailed evaluation of the following requirement analysis response for an AI-powered Study Companion Discord Bot.\n    \n    Evaluate based on these specific criteria:\n    1. Clarity (1-10): Is the response well-structured, organized logically, and easy to understand?\n    2. Completeness (1-10): Does it thoroughly cover both functional and non-functional requirements?\n    3. Technical Accuracy (1-10): Are the statements factually correct and aligned with software engineering best practices?\n    4. Specificity (1-10): Does it provide concrete, actionable details rather than vague statements?\n    5. Feasibility (1-10): Are the requirements realistic and implementable?\n    \n    Response to evaluate:\n    Based on the refined Discord Bot Requirements: AI-Powered Study Companion, I've organized the key points into a concise and structured format for your reference:\n\n**Discord Bot Requirements: AI-Powered Study Companion**\n\nI. **Core Principles**\n\n* Deliver a seamless and personalized user experience\n* Emphasize empathy, understanding, and human interaction\n* Incorporate user-centered design principles and human-computer interaction techniques\n\nII. **Section 1: User Interaction and Profile Management**\n\nA. **Intuitive Chat Interface Design**\n\n1. Clear onboarding and support mechanisms\n2. Customizable notification settings\n3. Emojis and emoticons for enhanced user engagement\n\nB. Personalized Learning Profiles\n\n1. AI-driven learning profiles that adapt to individual:\n\t* Learning styles (e.g., visual, auditory, kinesthetic)\n\t* Goals and objectives (e.g., academic, professional, personal)\n\t* Preferences for resource types (e.g., textbooks, articles, videos)\n\nIII. **Section 2: Real-Time Study Support and Personalized Tutoring**\n\nA. Emotional Intelligence and Empathy in Chatbot Interactions\n\n1. Text-based sentiment analysis\n2. Emotional state detection (e.g., stress, anxiety, excitement)\n3. Predefined response templates for common user emotions\n\nB. Adaptive Learning Pathways with Gamification and Motivation\n\n1. Points system for completing study sessions and achieving milestones\n2. Badges and leaderboards for tracking progress and competition\n3. Personalized motivational messages and encouragement\n\nIV. **Section 3: Performance and Scalability**\n\nA. High-Performance Server Architecture with Load Management\n\n1. Cloud-based infrastructure (e.g., AWS, Google Cloud)\n2. Caching mechanisms for improving response times\n3. Automated scaling to handle increased traffic and user demand\n\nB. User Feedback Mechanism with Real-Time Insights\n\n1. User performance and progress metrics (e.g., accuracy, completion rate)\n2. Study session duration and engagement metrics (e.g., time spent on task, number of questions attempted)\n\nV. **Section 4: Security Measures**\n\nA. Advanced Data Encryption Protocols with End-to-End Encryption\n\n1. SSL/TLS certificates\n2. AES-256 bit encryption\n3. Secure key management and storage\n\nVI. **Section 5: Integration Capabilities**\n\nA. Calendar Integration with Scheduling, Reminders, and Notifications\n\n1. Scheduling study sessions and reminders\n2. Customizable notification preferences and alerts\n\nB. Third-Party App Integration with Collaboration and Sharing\n\n1. Educational platforms (e.g., Coursera, edX)\n2. Productivity tools (e.g., Evernote, Trello)\n\nVII. **Section 6: Additional Requirements**\n\nA. Bot Maintenance Schedule with Human Oversight and Communication\n\n1. Bi-weekly updates and patches\n2. Quarterly security audits and vulnerability assessments\n3. Monthly user feedback sessions to gather insights and improve performance\n    \n    Format your response exactly as follows:\n    Clarity: [score]/10\n    Completeness: [score]/10\n    Technical Accuracy: [score]/10\n    Specificity: [score]/10\n    Feasibility: [score]/10\n    Overall: [average score]/10\n    \n    Explanation: [brief just ...
# ✓ Refined prompt score: 413.40
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[1], line 334
#     332 # Run the optimization pipeline
#     333 if __name__ == "__main__":
# --> 334     optimize_prompt_pipeline()
#
# Cell In[1], line 292, in optimize_prompt_pipeline()
#     290 # Save to history
#     291 timestamp = time.strftime("%Y%m%d_%H%M%S")
# --> 292 best_prompt_history[timestamp] = {
#     293     "prompt": champion["prompt"],
#     294     "score": champion["score"],
#     295     "metrics": champion["metrics"]
#     296 }
#     298 # Save top 3 prompts to file
#     299 with open("best_prompts.json", "w") as file:
#     300     # Only store recent and high-scoring prompts (up to 20)
#
# UnboundLocalError: cannot access local variable 'best_prompt_history' where it is not associated with a value
